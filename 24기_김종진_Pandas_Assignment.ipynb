# %% [markdown]
# ## Pandas 과제
#
# Tabular data의 경우 모델을 돌리기에 앞서서 pandas를 통한 전처리가 많이 필요합니다.
#
# 다음 과제에서는 판다스에서 가장 자주 쓰이는 함수들을 다룹니다.
#
# 구글에 올라와 있는 판다스 연습문제 200제 중 중복되는 것, 불필요하다고 생각되는 것을 제외하여 과제를 만들게 되었습니다.
#
# 넘파이 관련 문제들도 있었지만 판다스로만 과제를 구성하게 되었고, 그것들도 풀어보고 싶은 분들은 아래 출처를 남겨 놓았으니 참고하세요.
#
# 약 150개 정도로 문제 수가 많지만 기초적인 문제들이 많기 때문에 시간이 좀 걸릴 뿐 큰 어려움은 없을 거라 생각합니다.
#
# 문제를 풀다보면 부자연스러운 문제도 많이 있지만 그냥 연습 삼아 풀어보시기 바랍니다.
#
# 관련 csv파일들은 별도의 파일에 담아놓았습니다.
#
#
#  발제자: DA 23기 양진성

# %% [markdown]
# ### 출처
#
# Author: Avi Chawla
#
# LinkedIn: https://www.linkedin.com/in/avi-chawla/
#
# Read my blogs here: https://medium.com/@avi_chawla

# %% [markdown]
# - **Pandas**
#
# 1. Pandas Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-1-d693ac55-6455-40cf-ae34-867c6a02014e/%2Fnotebook.ipynb)
# 2. Pandas Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-employee-dataset-7e3b6755-5d4b-464b-9b75-9c84667ae3bd/%2Fnotebook.ipynb)
#
# 3. Pandas Notebook 3: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-employee-part-2-adc5a3ee-5f61-4725-8e46-ccb07899acfc/%2Fnotebook.ipynb)
#
# 4. Pandas Notebook 4: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-after-employee-f84e02a1-fb6a-428e-af90-8dd99855749a/%2Fnotebook.ipynb) **(This Notebook)**
#
# - **NumPy**
#
# 1. NumPy Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Numpy-part-1-9b9979f2-b708-4292-b466-3d0157564c91/%2Fnotebook.ipynb)
#
# 2. NumPy Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/NumPy-Notebook-2-4456411e-2ddd-426d-8027-4881080027db/%2Fnotebook.ipynb)
#
# 3. NumPy Notebook 3: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/NumPy-Notebook-3-e6587114-b580-4249-b599-540de859e603/%2Fnotebook.ipynb)
#
# - **SQL**
#
# 1. SQL Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/SQL-Notebook-1-eac9d782-a9b1-4e84-a1f9-af14080a6121/%2Fnotebook.ipynb)
#
# 2. SQL Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/SQL-Notebook-2-1914b214-be03-44a1-be63-ad99e98be639/%2Fnotebook.ipynb)

# %% [markdown]
# # Pandas Notebook 1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Create a Pandas DataFrame

# %% [markdown]
# ### 1. Create a DataFrame from a list of lists. Name the columns "col1", "col2" and "col3".

# %%
data_list = [[1,2,3], [4,5,6]]

df = pd.DataFrame(data_list, columns = ['col1', 'col2', 'cos3'])
print(df)
# Out:
#    col1  col2  cos3
# 0     1     2     3
# 1     4     5     6

# %% [markdown]
# ### 2. Create a DataFrame from a list of lists. Name the columns "col1", "col2" and "col3". Change the data type of all columns to "int8".

# %%
data_list = [[1,2,3], [4,5,6]]

df = pd.DataFrame(data_list, columns = ['col1', 'col2', 'cos3'], dtype = np.int8)
print(df)
print(df.dtypes)
# Out:
#    col1  col2  cos3
# 0     1     2     3
# 1     4     5     6
# col1    int8
# col2    int8
# cos3    int8
# dtype: object

# %% [markdown]
# ### 3. Create a DataFrame from a dictionary.

# %%
data_dict = {'col1': [1, 2], 'col2': [3, 4]}

df = pd.DataFrame(data_dict)
print(df)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %% [markdown]
# ### 4. Create a DataFrame from a dictionary. Change the data type to "int8".

# %%
data_dict = {'col1': [1, 2], 'col2': [3, 4]}

df = pd.DataFrame(data_dict,  dtype = np.int8)
print(df)
print(df.dtypes)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4
# col1    int8
# col2    int8
# dtype: object

# %% [markdown]
# ### 5. Create a DataFrame from a numpy array. Name the columns "col1", "col2" and "col3".

# %%
data_nparray = np.array([[1,2,3], [4,5,6]])

df = pd.DataFrame(data_nparray, columns = ['col1', 'col2', 'cos3'], dtype = np.int8)
print(df)
# Out:
#    col1  col2  cos3
# 0     1     2     3
# 1     4     5     6

# %% [markdown]
# ## Input Operations from CSV in Pandas

# %% [markdown]
# ### 6. Read a CSV File.

# %%
csv_file = "input_data/file1.csv"

df = pd.read_csv(csv_file)
print(df)
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %% [markdown]
# ### 7. Read a CSV file with delimiter "|".

# %%
csv_file = "input_data/file2.csv"

df = pd.read_csv(csv_file, delimiter = '|')
print(df)
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %% [markdown]
# ### 8. Read a CSV file with no header column and use "col1", "col2" and "col3" as column names. The delimiter is ",".

# %%
csv_file = "input_data/file3.csv"

df = pd.read_csv(csv_file, names = ['col1', 'col2', 'cos3'])
print(df)
# Out:
#    col1  col2  cos3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %% [markdown]
# ### 9. There are 3 columns in the file, namely "col1", "col2", and "col3". You have to read only "col1" and "col3".

# %%
csv_file = "input_data/file1.csv"

df = pd.read_csv(csv_file, usecols = ['col1', 'col3'])
print(df)
# Out:
#    col1  col3
# 0     1     3
# 1     4     6
# 2     7     9

# %% [markdown]
# ### 10. There are 3 columns in the file, namely "col1", "col2", and "col3". You have to read only "col1" and "col3". Moreover, the delimiter is "|".

# %%
csv_file = "input_data/file2.csv"

df =pd.read_csv(csv_file, usecols = ['col1', 'col3'], delimiter = '|')
print(df)
# Out:
#    col1  col3
# 0     1     3
# 1     4     6
# 2     7     9

# %% [markdown]
# ### 11. The file "file4.csv" has junk characters in the first two lines. You have to read the CSV file from the 3rd line.

# %%
csv_file = "input_data/file4.csv"

df = pd.read_csv(csv_file, skiprows = 2)
print(df)
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %% [markdown]
# ### 12. There are 3 columns in the file, namely "col1", "col2", and "col3". While reading the CSV file, specify the data type of "col1" as 'int32'.

# %%
csv_file = "input_data/file1.csv"

df = pd.read_csv(csv_file, dtype = {'col1' : 'int32'})
print(df)
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %% [markdown]
# ### 13. The first column in the CSV file holds index values of the dataframe. Read it so that the first column goes as the index column of the dataframe.

# %%
csv_file = "input_data/file5.csv"

df = pd.read_csv(csv_file, index_col = 0)
print(df)
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %% [markdown]
# ### 14. There are 9 data rows in the CSV file. Read only the first 4 of them.

# %% [markdown]
# Note: You should NOT read the whole CSV file and use the head() method to select the first 4 rows. 🚫

# %%
csv_file = "input_data/file6.csv"

df = pd.read_csv(csv_file, nrows = 4)
print(df)
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9
# 3     1     2     3

# %% [markdown]
# ## Output Operations to CSV in Pandas

# %% [markdown]
# ### 16. Given the dataframe "df", store it to a CSV File (with the index values).

# %%
df = pd.DataFrame([[1,2,3], [4,5,6]],
                  columns = ["col1", "col2", "col3"])

csv_file = "output_data/file1.csv"

## Start your code here
df.to_csv(csv_file, index=True)

## End your code here

# %% [markdown]
# ### 17. Given the dataframe "df", store it to a CSV File without the index column this time.

# %%
df = pd.DataFrame([[1,2,3], [4,5,6]],
                  columns = ["col1", "col2", "col3"])

csv_file = "output_data/file2.csv"

## Start your code here
df.to_csv(csv_file, index=False)


## End your code here

# %% [markdown]
# ### 20. Given a dataframe "df" with three columns -- "col1", "col2" and "col3". Store the DataFrame to a CSV file without the column row ( and without the index values).

# %%
df = pd.DataFrame([[1,2,3], [4,5,6]],
                  columns = ["col1", "col2", "col3"])

csv_file = "output_data/file5.csv"


## Start your code here
df.to_csv(csv_file, index=False, header = False)



## End your code here

# %% [markdown]
# # Pandas Notebook 2

# %% [markdown]
# ### 31. Read the CSV file.

# %%
import pandas as pd

# %%
file_name = "employee_dataset.csv"

df = pd.read_csv(file_name)

# %% [markdown]
# ### 32. Print the first 5 rows.

# %%
df.head(5)
# Out:
#              Name                  Company_Name  \
# 0  Spencer Adkins                James and Sons
# 1    Julie Morton                 Nichols-James
# 2    Matthew Hall                     Scott Inc
# 3      Brad Scott  Johnston, Fleming and Tanner
# 4   Theresa Owens      Baker, Allen and Edwards
#
#                         Employee_Job_Title      Employee_City  \
# 0                          Equities trader     New Russellton
# 1  Diplomatic Services operational officer  North Melissafurt
# 2               Regulatory affairs officer           Wardfort
# 3                      Production engineer     West Jamesview
# 4                      Production engineer          Whiteside
#
#         Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 0  Palestinian Territory           321520         Full Time              3.9
# 1       Marshall Islands           589090         Full Time              4.3
# 2               Anguilla           630890         Full Time              3.1
# 3   Syrian Arab Republic           116400         Full Time              3.1
# 4               Dominica           523499         Full Time              4.8

# %% [markdown]
# ### 33. Print the last 10 rows.

# %%
df.tail(10)
# Out:
#                      Name                  Company_Name  \
# 299990      Monica Bender    Wallace, Smith and Shepard
# 299991  William Rodriguez                     Scott Inc
# 299992    Steven Thornton      Baker, Allen and Edwards
# 299993         Terry Hill       White, Mcclain and Cobb
# 299994      Kelly Bennett       White, Mcclain and Cobb
# 299995         Nancy Neal              Bullock-Carrillo
# 299996     Michele Butler  Johnston, Fleming and Tanner
# 299997        Lynn Wilson                 Nichols-James
# 299998      Lindsey Keith                 Nichols-James
# 299999      Karen Delgado                James and Sons
#
#                   Employee_Job_Title      Employee_City Employee_Country  \
# 299990           Production engineer   New Cindychester       Bangladesh
# 299991                    Ergonomist          Whiteside      New Zealand
# 299992               Patent examiner         Aliciafort            Benin
# 299993  Investment banker, corporate   New Cindychester           Sweden
# 299994     Radiographer, therapeutic           Wardfort             Fiji
# 299995                   Optometrist  North Melissafurt            Samoa
# 299996                 Administrator         Aliciafort             Cuba
# 299997                 Administrator   New Cindychester          Bolivia
# 299998                          Make       Whitakerbury   Western Sahara
# 299999                       Actuary     New Russellton   United Kingdom
#
#         Employee_Salary Employment_Status  Employee_Rating
# 299990           852660         Full Time              3.0
# 299991           214400         Full Time              1.5
# 299992            60240         Full Time              4.3
# 299993           414720            Intern              2.3
# 299994           182270         Full Time              3.6
# 299995            99670            Intern              3.3
# 299996           949580            Intern              2.6
# 299997           802830         Full Time              0.6
# 299998           257240         Full Time              2.4
# 299999           575770            Intern              3.3

# %% [markdown]
# ### 34. Print the number of rows.

# %%
rows = len(df)

print(rows)
# Out:
# 300000

# %% [markdown]
# ### 35. Print the number of columns.

# %%
columns = len(df.columns)

print(columns)
# Out:
# 8

# %% [markdown]
# ### 36. Print all column names.

# %%
column_names = df.columns

print(column_names)
# Out:
# Index(['Name', 'Company_Name', 'Employee_Job_Title', 'Employee_City',
#        'Employee_Country', 'Employee_Salary', 'Employment_Status',
#        'Employee_Rating'],
#       dtype='object')

# %% [markdown]
# ### 37. Print the mean of Employee_Salary.

# %%
df['Employee_Salary'].mean()
# Out:
# 500224.20772666665

# %% [markdown]
# ### 38. Print the mean of Employee_Rating.

# %%
df['Employee_Rating'].mean()
# Out:
# 2.5059550000000006

# %% [markdown]
# ### 39. Print the number of distinct Company_Name.

# %%
df['Company_Name'].nunique()
# Out:
# 15

# %% [markdown]
# ### 41. Print the number of employees working in the company "Nichols-James".

# %%
len(df.query('Company_Name == "Nichols-James"'))
# Out:
# 19911

# %% [markdown]
# ### 42-44. Print the maximum, minimum and median Employee_Salary.

# %%
Employee_Salary = df[['Employee_Salary']]

Employee_Salary.max()
# Out:
# Employee_Salary    999990
# dtype: int64

# %%
Employee_Salary.min()
# Out:
# Employee_Salary    0
# dtype: int64

# %%
Employee_Salary.median()
# Out:
# Employee_Salary    500780.0
# dtype: float64

# %% [markdown]
# ### 45-49. Print the distribution of the following columns: (the frequency of individual entries).

# %% [markdown]
# 1. Company_Name

# %%
df['Company_Name'].value_counts()
# Out:
# Scott Inc                         20390
# White, Mcclain and Cobb           20261
# Thomas-Spencer                    20142
# Nelson-Li                         20132
# Taylor-Ramos                      20122
# Baker, Allen and Edwards          20084
# Matthews Inc                      20083
# Bullock-Carrillo                  20063
# Andrade LLC                       19983
# Campos, Reynolds and Mccormick    19927
# Nichols-James                     19911
# James and Sons                    19868
# Marshall-Holloway                 19859
# Johnston, Fleming and Tanner      19811
# Wallace, Smith and Shepard        19364
# Name: Company_Name, dtype: int64

# %% [markdown]
# 2. Employee_Job_Title

# %%
df['Employee_Job_Title'].value_counts()
# Out:
# Diplomatic Services operational officer                  30137
# Administrator                                            15222
# Garment/textile technologist                             15183
# Trading standards officer                                15155
# Patent examiner                                          15085
# Armed forces logistics/support/administrative officer    15050
# Retail merchandiser                                      15033
# Energy manager                                           15033
# Actuary                                                  15030
# Investment banker, corporate                             15008
# Ergonomist                                               15006
# Production engineer                                      15003
# Equities trader                                          15000
# Naval architect                                          14905
# Radiographer, therapeutic                                14882
# Regulatory affairs officer                               14869
# Optometrist                                              14838
# Sales promotion account executive                        14820
# Make                                                     14741
# Name: Employee_Job_Title, dtype: int64

# %% [markdown]
# ### 50. Print the company with the most number of employees.

# %%
company_name = df['Company_Name'].value_counts()
company_name.idxmax()
# Out:
# 'Scott Inc'

# %% [markdown]
# ### 51. Print the number of employees in the above company.

# %%
company_name.max()
# Out:
# 20390

# %% [markdown]
# ### 52. Print the company with the least number of employees.

# %%
company_name.idxmin()
# Out:
# 'Wallace, Smith and Shepard'

# %% [markdown]
# ### 53. Print the number of employees in the above company.

# %%
company_name.min()
# Out:
# 19364

# %% [markdown]
# ### 54. Print the employee details with the maximum salary

# %%
salary = df.sort_values('Employee_Salary', ascending = False)

salary[salary['Employee_Salary'] == salary['Employee_Salary'].max()]
# Out:
#               Name  Company_Name   Employee_Job_Title Employee_City  \
# 70356  Anna Lawson  Taylor-Ramos  Production engineer   Kristaburgh
#
#       Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 70356          Lesotho           999990         Full Time              4.0

# %% [markdown]
# ### 55. Print the employee details with the maximum rating

# %%
rating = df.sort_values('Employee_Rating', ascending = False)

rating[rating['Employee_Rating'] == rating['Employee_Rating'].max()]
# Out:
#                      Name                  Company_Name  \
# 222544        Laura Lopez                     Scott Inc
# 26453     Adriana Ferrell  Johnston, Fleming and Tanner
# 141265     Russell Dorsey      Baker, Allen and Edwards
# 184624  Katherine Jenkins                  Matthews Inc
# 70533     Brittney Greene                James and Sons
# ...                   ...                           ...
# 20027       Jonathan Wong                  Matthews Inc
# 84820        Jesse Acosta                   Andrade LLC
# 46507       Andrew Palmer             Marshall-Holloway
# 175614     William Peters       White, Mcclain and Cobb
# 30818      Victoria Patel             Marshall-Holloway
#
#                                        Employee_Job_Title     Employee_City  \
# 222544                                    Equities trader         Whiteside
# 26453                                          Ergonomist        Aliciafort
# 141265                                        Optometrist        Aliciafort
# 184624                                               Make  New Cindychester
# 70533                                      Energy manager      Ricardomouth
# ...                                                   ...               ...
# 20027   Armed forces logistics/support/administrative ...      Ricardomouth
# 84820                                     Patent examiner        Aliciafort
# 46507                                      Energy manager        Aliciafort
# 175614                                         Ergonomist         Whiteside
# 30818                                       Administrator         Whiteside
#
#                   Employee_Country  Employee_Salary Employment_Status  \
# 222544      British Virgin Islands           271140         Full Time
# 26453                        Gabon           678800            Intern
# 141265                     Morocco           816320         Full Time
# 184624                       Nauru           498850         Full Time
# 70533                     Bulgaria           332780         Full Time
# ...                            ...              ...               ...
# 20027                   Luxembourg            69130            Intern
# 84820   Slovakia (Slovak Republic)           353470            Intern
# 46507                        Samoa           949400         Full Time
# 175614                     Austria            61780         Full Time
# 30818                  Puerto Rico           746410            Intern
#
#         Employee_Rating
# 222544              5.0
# 26453               5.0
# 141265              5.0
# 184624              5.0
# 70533               5.0
# ...                 ...
# 20027               5.0
# 84820               5.0
# 46507               5.0
# 175614              5.0
# 30818               5.0
#
# [2985 rows x 8 columns]

# %% [markdown]
# ### 56. Print the Company_Name with most number of employees in 'Wardfort' city.

# %%
wardfort = df.query('Employee_City == "Wardfort"')
company = wardfort['Company_Name'].value_counts()
company.idxmax()
# Out:
# 'White, Mcclain and Cobb'

# %% [markdown]
# ### 57. Change the Data type of 'Employee_Salary' column to float.

# %%
df['Employee_Salary'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Name                300000 non-null  object
#  1   Company_Name        300000 non-null  object
#  2   Employee_Job_Title  300000 non-null  object
#  3   Employee_City       300000 non-null  object
#  4   Employee_Country    300000 non-null  object
#  5   Employee_Salary     300000 non-null  int64
#  6   Employment_Status   300000 non-null  object
#  7   Employee_Rating     300000 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 18.3+ MB

# %% [markdown]
# ### 58. Print the Employee_City with the most number of 'Production engineer'.

# %%
production_engineer = df.query('Employee_Job_Title == "Production engineer"')
production_engineer['Employee_City'].value_counts().idxmax()
# Out:
# 'Aliciafort'

# %% [markdown]
# ### 60. Print the Company_Name with the highest average 'Employee_Rating'.

# %%
Company_Name = df.groupby('Company_Name')['Employee_Rating'].mean()
Company_Name.idxmax()
# Out:
# 'Matthews Inc'

# %% [markdown]
# ### 61. Print the number of employees working in 'Ricardomouth' and 'Kristaburgh' location combined.

# %%
df.query("Employee_City in ['Ricardomouth','Kristaburgh']")
# Out:
#                      Name                    Company_Name  \
# 5           Vanessa Allen                     Andrade LLC
# 7             Vicki Beard                    Matthews Inc
# 11        Timothy Johnson        Baker, Allen and Edwards
# 15           David Massey    Johnston, Fleming and Tanner
# 22         Carlos Lindsey                   Nichols-James
# ...                   ...                             ...
# 299948       Amy Martinez  Campos, Reynolds and Mccormick
# 299950        Stacey Hart                    Matthews Inc
# 299956        Leah Miller                  Thomas-Spencer
# 299960  Alexander Kaufman    Johnston, Fleming and Tanner
# 299969   Jennifer Navarro    Johnston, Fleming and Tanner
#
#                                        Employee_Job_Title Employee_City  \
# 5                                                    Make  Ricardomouth
# 7                 Diplomatic Services operational officer   Kristaburgh
# 11                             Regulatory affairs officer  Ricardomouth
# 15                              Radiographer, therapeutic  Ricardomouth
# 22                                        Patent examiner   Kristaburgh
# ...                                                   ...           ...
# 299948                                    Naval architect  Ricardomouth
# 299950  Armed forces logistics/support/administrative ...  Ricardomouth
# 299956                                         Ergonomist   Kristaburgh
# 299960            Diplomatic Services operational officer  Ricardomouth
# 299969                       Investment banker, corporate   Kristaburgh
#
#               Employee_Country  Employee_Salary Employment_Status  \
# 5                         Mali           850140         Full Time
# 7               Western Sahara           777000         Full Time
# 11                     Georgia           503610         Full Time
# 15                     Somalia           581490            Intern
# 22                      Jersey           629640            Intern
# ...                        ...              ...               ...
# 299948  Bosnia and Herzegovina           476650         Full Time
# 299950                Pakistan           743730         Full Time
# 299956                Cameroon           765320         Full Time
# 299960                   Congo           729070         Full Time
# 299969                   Nauru           472090         Full Time
#
#         Employee_Rating
# 5                   2.6
# 7                   3.3
# 11                  2.9
# 15                  3.7
# 22                  0.3
# ...                 ...
# 299948              3.9
# 299950              3.1
# 299956              1.8
# 299960              1.0
# 299969              4.3
#
# [60256 rows x 8 columns]

# %% [markdown]
# ### 62. Print the distinct Company_Name corresponding to the 5 highest paid employees in the dataset.

# %%
df.sort_values('Employee_Salary', ascending = False).head()['Company_Name'].unique()
# Out:
# array(['Taylor-Ramos', 'Thomas-Spencer', 'White, Mcclain and Cobb',
#        'Campos, Reynolds and Mccormick'], dtype=object)

# %% [markdown]
# ### 63. Check if there are any duplicate rows in the DataFrame.

# %%
df[df.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Name, Company_Name, Employee_Job_Title, Employee_City, Employee_Country, Employee_Salary, Employment_Status, Employee_Rating]
# Index: []

# %% [markdown]
# ### 64. Check if any of the columns has NaN values.

# %%
df.isna().sum()
# Out:
# Name                  0
# Company_Name          0
# Employee_Job_Title    0
# Employee_City         0
# Employee_Country      0
# Employee_Salary       0
# Employment_Status     0
# Employee_Rating       0
# dtype: int64

# %% [markdown]
# ### 65. Print the data type of every column in the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Name                300000 non-null  object
#  1   Company_Name        300000 non-null  object
#  2   Employee_Job_Title  300000 non-null  object
#  3   Employee_City       300000 non-null  object
#  4   Employee_Country    300000 non-null  object
#  5   Employee_Salary     300000 non-null  int64
#  6   Employment_Status   300000 non-null  object
#  7   Employee_Rating     300000 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 18.3+ MB

# %% [markdown]
# ### 66. Print the Company_Name column only as a Series

# %%
df['Company_Name']
# Out:
# 0                       James and Sons
# 1                        Nichols-James
# 2                            Scott Inc
# 3         Johnston, Fleming and Tanner
# 4             Baker, Allen and Edwards
#                       ...
# 299995                Bullock-Carrillo
# 299996    Johnston, Fleming and Tanner
# 299997                   Nichols-James
# 299998                   Nichols-James
# 299999                  James and Sons
# Name: Company_Name, Length: 300000, dtype: object

# %% [markdown]
# ### 67. Print the Company_Name column only as a DataFrame

# %%
df[['Company_Name']]
# Out:
#                         Company_Name
# 0                     James and Sons
# 1                      Nichols-James
# 2                          Scott Inc
# 3       Johnston, Fleming and Tanner
# 4           Baker, Allen and Edwards
# ...                              ...
# 299995              Bullock-Carrillo
# 299996  Johnston, Fleming and Tanner
# 299997                 Nichols-James
# 299998                 Nichols-James
# 299999                James and Sons
#
# [300000 rows x 1 columns]

# %% [markdown]
# ### 68. Select the 'Employee_Job_Title' and 'Employee_City' column.

# %%
df[['Employee_Job_Title', 'Employee_City']]
# Out:
#                              Employee_Job_Title      Employee_City
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299995                              Optometrist  North Melissafurt
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
#
# [300000 rows x 2 columns]

# %% [markdown]
# ### 69. Print the number of employees with Employee_Rating greater than the average Employee_Rating

# %%
average_rating = df['Employee_Rating'].mean()
len(df[df['Employee_Rating'] > average_rating])
# Out:
# 147548

# %% [markdown]
# ### 74. Print the first 5 rows of the first 5 columns.

# %%
df.iloc[:5,:5]
# Out:
#              Name                  Company_Name  \
# 0  Spencer Adkins                James and Sons
# 1    Julie Morton                 Nichols-James
# 2    Matthew Hall                     Scott Inc
# 3      Brad Scott  Johnston, Fleming and Tanner
# 4   Theresa Owens      Baker, Allen and Edwards
#
#                         Employee_Job_Title      Employee_City  \
# 0                          Equities trader     New Russellton
# 1  Diplomatic Services operational officer  North Melissafurt
# 2               Regulatory affairs officer           Wardfort
# 3                      Production engineer     West Jamesview
# 4                      Production engineer          Whiteside
#
#         Employee_Country
# 0  Palestinian Territory
# 1       Marshall Islands
# 2               Anguilla
# 3   Syrian Arab Republic
# 4               Dominica

# %% [markdown]
# ### 76. Print the number of employees whose first name starts with the letter 'V'.

# %%
len(df[df['Name'].str.startswith('V')])
# Out:
# 3683

# %% [markdown]
# ### 77. Print the number of employees whose last name starts with the letter 'R'.

# %%
df['Last_Name'] = df['Name'].str.split().str[-1]
df[df['Last_Name'].str.startswith('R')]
# Out:
#                      Name                Company_Name  \
# 17              Gail Rose              Thomas-Spencer
# 26        Donna Rodriguez              Thomas-Spencer
# 28           Kim Reynolds           Marshall-Holloway
# 39          Jessica Reyes              Thomas-Spencer
# 55            Amanda Roth                Taylor-Ramos
# ...                   ...                         ...
# 299902  Michelle Reynolds           Marshall-Holloway
# 299905       Sandra Riley  Wallace, Smith and Shepard
# 299964   Joshua Rodriguez                 Andrade LLC
# 299967       James Rhodes                Matthews Inc
# 299991  William Rodriguez                   Scott Inc
#
#                        Employee_Job_Title      Employee_City  \
# 17                        Patent examiner       Whitakerbury
# 26      Sales promotion account executive          Whiteside
# 28                                Actuary     West Jamesview
# 39           Garment/textile technologist        Kristaburgh
# 55                          Administrator  North Melissafurt
# ...                                   ...                ...
# 299902                               Make           Wardfort
# 299905                     Energy manager          Whiteside
# 299964          Trading standards officer   New Cindychester
# 299967                Production engineer   New Cindychester
# 299991                         Ergonomist          Whiteside
#
#                 Employee_Country  Employee_Salary Employment_Status  \
# 17                       Finland           178570         Full Time
# 26                          Guam           622920         Full Time
# 28                 Faroe Islands           794450         Full Time
# 39                      Botswana           667490         Full Time
# 55                     Macedonia           437720         Full Time
# ...                          ...              ...               ...
# 299902               El Salvador           105680         Full Time
# 299905  Northern Mariana Islands            34760         Full Time
# 299964              Sierra Leone           118300         Full Time
# 299967                  Honduras           386610         Full Time
# 299991               New Zealand           214400         Full Time
#
#         Employee_Rating  Last_Name
# 17                  1.9       Rose
# 26                  2.8  Rodriguez
# 28                  1.4   Reynolds
# 39                  0.7      Reyes
# 55                  0.7       Roth
# ...                 ...        ...
# 299902              4.8   Reynolds
# 299905              2.0      Riley
# 299964              1.1  Rodriguez
# 299967              1.4     Rhodes
# 299991              1.5  Rodriguez
#
# [20712 rows x 9 columns]

# %% [markdown]
# ### 78. Select the rows 2 to 7 and the columns 3 to 7 (both included)

# %%
df.iloc[2:8,3:8]
# Out:
#     Employee_City      Employee_Country  Employee_Salary Employment_Status  \
# 2        Wardfort              Anguilla           630890         Full Time
# 3  West Jamesview  Syrian Arab Republic           116400         Full Time
# 4       Whiteside              Dominica           523499         Full Time
# 5    Ricardomouth                  Mali           850140         Full Time
# 6        Wardfort                 Aruba           711410         Full Time
# 7     Kristaburgh        Western Sahara           777000         Full Time
#
#    Employee_Rating
# 2              3.1
# 3              3.1
# 4              4.8
# 5              2.6
# 6              2.0
# 7              3.3

# %% [markdown]
# ### 79. Select every row after the 10th row and select all columns.

# %%
df.iloc[10:]
# Out:
#                    Name                    Company_Name  \
# 10      Victoria Sutton         White, Mcclain and Cobb
# 11      Timothy Johnson        Baker, Allen and Edwards
# 12       Tiffany Galvan  Campos, Reynolds and Mccormick
# 13          David Duran                   Nichols-James
# 14           Julie Cook                    Matthews Inc
# ...                 ...                             ...
# 299995       Nancy Neal                Bullock-Carrillo
# 299996   Michele Butler    Johnston, Fleming and Tanner
# 299997      Lynn Wilson                   Nichols-James
# 299998    Lindsey Keith                   Nichols-James
# 299999    Karen Delgado                  James and Sons
#
#                              Employee_Job_Title      Employee_City  \
# 10                              Naval architect          Whiteside
# 11                   Regulatory affairs officer       Ricardomouth
# 12      Diplomatic Services operational officer     West Jamesview
# 13                 Investment banker, corporate     New Russellton
# 14                              Equities trader     New Russellton
# ...                                         ...                ...
# 299995                              Optometrist  North Melissafurt
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
#
#        Employee_Country  Employee_Salary Employment_Status  Employee_Rating  \
# 10               Poland           656260         Full Time              4.9
# 11              Georgia           503610         Full Time              2.9
# 12                Niger           786430            Intern              3.6
# 13              Georgia           910210         Full Time              4.9
# 14          Puerto Rico           328860         Full Time              4.8
# ...                 ...              ...               ...              ...
# 299995            Samoa            99670            Intern              3.3
# 299996             Cuba           949580            Intern              2.6
# 299997          Bolivia           802830         Full Time              0.6
# 299998   Western Sahara           257240         Full Time              2.4
# 299999   United Kingdom           575770            Intern              3.3
#
#        Last_Name
# 10        Sutton
# 11       Johnson
# 12        Galvan
# 13         Duran
# 14          Cook
# ...          ...
# 299995      Neal
# 299996    Butler
# 299997    Wilson
# 299998     Keith
# 299999   Delgado
#
# [299990 rows x 9 columns]

# %% [markdown]
# ### 83. Print the name of the company with the maximum employees having rating > 4.

# %%
df[df['Employee_Rating'] > 4]['Company_Name'].value_counts().idxmax()
# Out:
# 'Matthews Inc'

# %% [markdown]
# ### 88. Which is the most common first name in the dataframe?

# %%
df['First_Name'] = df['Name'].str.split().str[0]
df['First_Name'].value_counts().idxmax()
# Out:
# 'Michael'

# %% [markdown]
# ### 90. What is the average name length?

# %%
df['Name_Length'] = df['Name'].str.len()
df['Name_Length'].mean()
# Out:
# 13.1079

# %% [markdown]
# # Pandas Notebook 3

# %%
import pandas as pd

# %%
df = pd.read_csv("employee_dataset.csv")

# %% [markdown]
# ### 91. What is the ratio of total full-time employees to Interns?

# %%
len(df[df['Employment_Status'] == 'Full Time']) / len(df[df['Employment_Status'] == 'Intern'])
# Out:
# 4.0008334722453744

# %% [markdown]
# ### 92. Starting from the first record, print every third record in the DataFrame.

# %% [markdown]
# Print 1st row, then 4th, 7th, 10th, and so on...

# %%
df.iloc[::3]
# Out:
#                      Name                    Company_Name  \
# 0          Spencer Adkins                  James and Sons
# 3              Brad Scott    Johnston, Fleming and Tanner
# 6             Kelly Brown                     Andrade LLC
# 9         Michael Edwards  Campos, Reynolds and Mccormick
# 12         Tiffany Galvan  Campos, Reynolds and Mccormick
# ...                   ...                             ...
# 299985      Chase Stevens                       Nelson-Li
# 299988     Kenneth Hurley                       Scott Inc
# 299991  William Rodriguez                       Scott Inc
# 299994      Kelly Bennett         White, Mcclain and Cobb
# 299997        Lynn Wilson                   Nichols-James
#
#                              Employee_Job_Title     Employee_City  \
# 0                               Equities trader    New Russellton
# 3                           Production engineer    West Jamesview
# 6                               Naval architect          Wardfort
# 9                                    Ergonomist  New Cindychester
# 12      Diplomatic Services operational officer    West Jamesview
# ...                                         ...               ...
# 299985                           Energy manager      Whitakerbury
# 299988                                     Make    New Russellton
# 299991                               Ergonomist         Whiteside
# 299994                Radiographer, therapeutic          Wardfort
# 299997                            Administrator  New Cindychester
#
#                         Employee_Country  Employee_Salary Employment_Status  \
# 0                  Palestinian Territory           321520         Full Time
# 3                   Syrian Arab Republic           116400         Full Time
# 6                                  Aruba           711410         Full Time
# 9       Lao People's Democratic Republic           516950         Full Time
# 12                                 Niger           786430            Intern
# ...                                  ...              ...               ...
# 299985          Northern Mariana Islands           590590         Full Time
# 299988                Russian Federation           211180         Full Time
# 299991                       New Zealand           214400         Full Time
# 299994                              Fiji           182270         Full Time
# 299997                           Bolivia           802830         Full Time
#
#         Employee_Rating
# 0                   3.9
# 3                   3.1
# 6                   2.0
# 9                   2.3
# 12                  3.6
# ...                 ...
# 299985              2.6
# 299988              3.9
# 299991              1.5
# 299994              3.6
# 299997              0.6
#
# [100000 rows x 8 columns]

# %% [markdown]
# ### 93. Find the average salary for every company.

# %%
df.groupby('Company_Name')['Employee_Salary'].mean()
# Out:
# Company_Name
# Andrade LLC                       497237.159385
# Baker, Allen and Edwards          498032.358445
# Bullock-Carrillo                  499603.804865
# Campos, Reynolds and Mccormick    503528.982687
# James and Sons                    503581.015754
# Johnston, Fleming and Tanner      500579.128010
# Marshall-Holloway                 502314.169445
# Matthews Inc                      501640.159488
# Nelson-Li                         500569.824558
# Nichols-James                     497881.232334
# Scott Inc                         500491.809024
# Taylor-Ramos                      498747.292516
# Thomas-Spencer                    499350.850164
# Wallace, Smith and Shepard        500807.608810
# White, Mcclain and Cobb           499083.493806
# Name: Employee_Salary, dtype: float64

# %% [markdown]
# ### 95. Find the average salary and average rating for every company in a single line.

# %%
df.groupby('Company_Name').mean()
# Out:
# <ipython-input-317-299b181b1bf4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Company_Name').mean()
#                                 Employee_Salary  Employee_Rating
# Company_Name
# Andrade LLC                       497237.159385         2.498218
# Baker, Allen and Edwards          498032.358445         2.504795
# Bullock-Carrillo                  499603.804865         2.502014
# Campos, Reynolds and Mccormick    503528.982687         2.506288
# James and Sons                    503581.015754         2.505023
# Johnston, Fleming and Tanner      500579.128010         2.513159
# Marshall-Holloway                 502314.169445         2.504900
# Matthews Inc                      501640.159488         2.525454
# Nelson-Li                         500569.824558         2.504649
# Nichols-James                     497881.232334         2.488554
# Scott Inc                         500491.809024         2.515993
# Taylor-Ramos                      498747.292516         2.513150
# Thomas-Spencer                    499350.850164         2.505114
# Wallace, Smith and Shepard        500807.608810         2.497402
# White, Mcclain and Cobb           499083.493806         2.504047

# %% [markdown]
# ### 96. Find the number of unique Employee_City corresponding to every Company_Name.

# %%
df.groupby('Company_Name')['Employee_City'].nunique()
# Out:
# Company_Name
# Andrade LLC                       10
# Baker, Allen and Edwards          10
# Bullock-Carrillo                  10
# Campos, Reynolds and Mccormick    10
# James and Sons                    10
# Johnston, Fleming and Tanner      10
# Marshall-Holloway                 10
# Matthews Inc                      10
# Nelson-Li                         10
# Nichols-James                     10
# Scott Inc                         10
# Taylor-Ramos                      10
# Thomas-Spencer                    10
# Wallace, Smith and Shepard        10
# White, Mcclain and Cobb           10
# Name: Employee_City, dtype: int64

# %% [markdown]
# ### 98. Print the number of full-time and intern employees for every company

# %%
df.groupby('Company_Name')['Employment_Status'].value_counts()
# Out:
# Company_Name                    Employment_Status
# Andrade LLC                     Full Time            15964
#                                 Intern                4019
# Baker, Allen and Edwards        Full Time            16118
#                                 Intern                3966
# Bullock-Carrillo                Full Time            16135
#                                 Intern                3928
# Campos, Reynolds and Mccormick  Full Time            15930
#                                 Intern                3997
# James and Sons                  Full Time            15888
#                                 Intern                3980
# Johnston, Fleming and Tanner    Full Time            15832
#                                 Intern                3979
# Marshall-Holloway               Full Time            15871
#                                 Intern                3988
# Matthews Inc                    Full Time            16082
#                                 Intern                4001
# Nelson-Li                       Full Time            16027
#                                 Intern                4105
# Nichols-James                   Full Time            15872
#                                 Intern                4039
# Scott Inc                       Full Time            16396
#                                 Intern                3994
# Taylor-Ramos                    Full Time            16086
#                                 Intern                4036
# Thomas-Spencer                  Full Time            16037
#                                 Intern                4105
# Wallace, Smith and Shepard      Full Time            15467
#                                 Intern                3897
# White, Mcclain and Cobb         Full Time            16305
#                                 Intern                3956
# Name: Employment_Status, dtype: int64

# %% [markdown]
# ### 99. Print the job title with the most employees.

# %%
df['Employee_Job_Title'].value_counts().idxmax()
# Out:
# 'Diplomatic Services operational officer'

# %% [markdown]
# ### 107. Check if the substring 'Michael Edward' appears in the Name column or not.

# %%
df[df['Name'].str.contains('Michael Edward')]
# Out:
#                    Name                    Company_Name  \
# 9       Michael Edwards  Campos, Reynolds and Mccormick
# 5255    Michael Edwards    Johnston, Fleming and Tanner
# 18849   Michael Edwards         White, Mcclain and Cobb
# 25616   Michael Edwards                Bullock-Carrillo
# 31519   Michael Edwards                       Nelson-Li
# 112668  Michael Edwards                       Scott Inc
# 114386  Michael Edwards                   Nichols-James
# 124065  Michael Edwards         White, Mcclain and Cobb
# 135078  Michael Edwards                    Matthews Inc
# 149363  Michael Edwards                       Scott Inc
# 158104  Michael Edwards      Wallace, Smith and Shepard
# 191831  Michael Edwards      Wallace, Smith and Shepard
# 193911  Michael Edwards        Baker, Allen and Edwards
# 205550  Michael Edwards    Johnston, Fleming and Tanner
# 210504  Michael Edwards         White, Mcclain and Cobb
# 217498  Michael Edwards    Johnston, Fleming and Tanner
# 217970  Michael Edwards                Bullock-Carrillo
# 227767  Michael Edwards               Marshall-Holloway
# 229786  Michael Edwards                       Scott Inc
# 267189  Michael Edwards                  James and Sons
# 276731  Michael Edwards  Campos, Reynolds and Mccormick
# 282601  Michael Edwards         White, Mcclain and Cobb
# 287887  Michael Edwards                       Scott Inc
# 298857  Michael Edwards         White, Mcclain and Cobb
#
#                                        Employee_Job_Title      Employee_City  \
# 9                                              Ergonomist   New Cindychester
# 5255                           Regulatory affairs officer     West Jamesview
# 18849   Armed forces logistics/support/administrative ...          Whiteside
# 25616                           Trading standards officer           Wardfort
# 31519                                     Patent examiner          Whiteside
# 112668                                    Equities trader     West Jamesview
# 114386                                    Patent examiner       Whitakerbury
# 124065            Diplomatic Services operational officer       Ricardomouth
# 135078                                    Patent examiner           Wardfort
# 149363            Diplomatic Services operational officer           Wardfort
# 158104                         Regulatory affairs officer     New Russellton
# 191831                          Trading standards officer         Aliciafort
# 193911                       Investment banker, corporate   New Cindychester
# 205550                                    Patent examiner           Wardfort
# 210504                                         Ergonomist          Whiteside
# 217498                                            Actuary           Wardfort
# 217970                                    Equities trader     West Jamesview
# 227767  Armed forces logistics/support/administrative ...  North Melissafurt
# 229786            Diplomatic Services operational officer       Whitakerbury
# 267189                                               Make       Ricardomouth
# 276731  Armed forces logistics/support/administrative ...  North Melissafurt
# 282601                                    Naval architect           Wardfort
# 287887                       Investment banker, corporate         Aliciafort
# 298857                                               Make   New Cindychester
#
#                         Employee_Country  Employee_Salary Employment_Status  \
# 9       Lao People's Democratic Republic           516950         Full Time
# 5255                              Brazil           822420            Intern
# 18849                            Croatia           818710         Full Time
# 25616                          Greenland           467160            Intern
# 31519                             Kuwait           287350         Full Time
# 112668          Northern Mariana Islands            21540         Full Time
# 114386                           Iceland           687630            Intern
# 124065          Central African Republic           546870         Full Time
# 135078                           Grenada           209030         Full Time
# 149363                             Chile           254160            Intern
# 158104                            Angola           121770         Full Time
# 191831                            Israel           854420         Full Time
# 193911                           Lesotho           365180         Full Time
# 205550                           Belgium           579130            Intern
# 210504                       Philippines           150730         Full Time
# 217498               Trinidad and Tobago           600090         Full Time
# 217970        Slovakia (Slovak Republic)           698220         Full Time
# 227767                             Ghana           565940            Intern
# 229786          Turks and Caicos Islands           105450            Intern
# 267189                          Paraguay           391700            Intern
# 276731                            Serbia           865280            Intern
# 282601                          Cambodia           855180            Intern
# 287887                            Belize            69680            Intern
# 298857                             Macao           318800         Full Time
#
#         Employee_Rating
# 9                   2.3
# 5255                3.5
# 18849               2.8
# 25616               2.1
# 31519               1.8
# 112668              1.5
# 114386              2.1
# 124065              1.4
# 135078              2.2
# 149363              1.2
# 158104              1.1
# 191831              4.8
# 193911              1.8
# 205550              4.7
# 210504              3.2
# 217498              0.8
# 217970              0.7
# 227767              4.4
# 229786              2.6
# 267189              1.4
# 276731              0.7
# 282601              4.7
# 287887              1.9
# 298857              3.6

# %% [markdown]
# ### 110. Print the number of records whose company name contains the substring 'LL' (case-insensitive).

# %%
df[df['Company_Name'].str.contains('LL', case = False)]
# Out:
#                    Name                Company_Name  \
# 4         Theresa Owens    Baker, Allen and Edwards
# 5         Vanessa Allen                 Andrade LLC
# 6           Kelly Brown                 Andrade LLC
# 11      Timothy Johnson    Baker, Allen and Edwards
# 18         Carrie Woods            Bullock-Carrillo
# ...                 ...                         ...
# 299977   Anthony Hughes            Bullock-Carrillo
# 299986      Chelsea Lee                 Andrade LLC
# 299990    Monica Bender  Wallace, Smith and Shepard
# 299992  Steven Thornton    Baker, Allen and Edwards
# 299995       Nancy Neal            Bullock-Carrillo
#
#                        Employee_Job_Title      Employee_City Employee_Country  \
# 4                     Production engineer          Whiteside         Dominica
# 5                                    Make       Ricardomouth             Mali
# 6                         Naval architect           Wardfort            Aruba
# 11             Regulatory affairs officer       Ricardomouth          Georgia
# 18                             Ergonomist     New Russellton            Gabon
# ...                                   ...                ...              ...
# 299977  Sales promotion account executive       Whitakerbury          Georgia
# 299986       Investment banker, corporate           Wardfort      Switzerland
# 299990                Production engineer   New Cindychester       Bangladesh
# 299992                    Patent examiner         Aliciafort            Benin
# 299995                        Optometrist  North Melissafurt            Samoa
#
#         Employee_Salary Employment_Status  Employee_Rating
# 4                523499         Full Time              4.8
# 5                850140         Full Time              2.6
# 6                711410         Full Time              2.0
# 11               503610         Full Time              2.9
# 18               985290         Full Time              2.4
# ...                 ...               ...              ...
# 299977           464910         Full Time              4.1
# 299986            88410         Full Time              4.4
# 299990           852660         Full Time              3.0
# 299992            60240         Full Time              4.3
# 299995            99670            Intern              3.3
#
# [99353 rows x 8 columns]

# %% [markdown]
# ### 111. Select the first row corresponding to every company in the dataframe

# %%
df.groupby('Company_Name').first()
#first(), last(), nth()
# Out:
#                                               Name  \
# Company_Name
# Andrade LLC                          Vanessa Allen
# Baker, Allen and Edwards             Theresa Owens
# Bullock-Carrillo                      Carrie Woods
# Campos, Reynolds and Mccormick     Michael Edwards
# James and Sons                      Spencer Adkins
# Johnston, Fleming and Tanner            Brad Scott
# Marshall-Holloway                   David Phillips
# Matthews Inc                           Vicki Beard
# Nelson-Li                       Micheal Fitzgerald
# Nichols-James                         Julie Morton
# Scott Inc                             Matthew Hall
# Taylor-Ramos                           Lisa French
# Thomas-Spencer                           Gail Rose
# Wallace, Smith and Shepard            Ronald Clark
# White, Mcclain and Cobb            Victoria Sutton
#
#                                                      Employee_Job_Title  \
# Company_Name
# Andrade LLC                                                        Make
# Baker, Allen and Edwards                            Production engineer
# Bullock-Carrillo                                             Ergonomist
# Campos, Reynolds and Mccormick                               Ergonomist
# James and Sons                                          Equities trader
# Johnston, Fleming and Tanner                        Production engineer
# Marshall-Holloway                             Radiographer, therapeutic
# Matthews Inc                    Diplomatic Services operational officer
# Nelson-Li                       Diplomatic Services operational officer
# Nichols-James                   Diplomatic Services operational officer
# Scott Inc                                    Regulatory affairs officer
# Taylor-Ramos                                  Radiographer, therapeutic
# Thomas-Spencer                                          Patent examiner
# Wallace, Smith and Shepard                   Regulatory affairs officer
# White, Mcclain and Cobb                                 Naval architect
#
#                                     Employee_City  \
# Company_Name
# Andrade LLC                          Ricardomouth
# Baker, Allen and Edwards                Whiteside
# Bullock-Carrillo                   New Russellton
# Campos, Reynolds and Mccormick   New Cindychester
# James and Sons                     New Russellton
# Johnston, Fleming and Tanner       West Jamesview
# Marshall-Holloway                     Kristaburgh
# Matthews Inc                          Kristaburgh
# Nelson-Li                            Whitakerbury
# Nichols-James                   North Melissafurt
# Scott Inc                                Wardfort
# Taylor-Ramos                       West Jamesview
# Thomas-Spencer                       Whitakerbury
# Wallace, Smith and Shepard      North Melissafurt
# White, Mcclain and Cobb                 Whiteside
#
#                                                 Employee_Country  \
# Company_Name
# Andrade LLC                                                 Mali
# Baker, Allen and Edwards                                Dominica
# Bullock-Carrillo                                           Gabon
# Campos, Reynolds and Mccormick  Lao People's Democratic Republic
# James and Sons                             Palestinian Territory
# Johnston, Fleming and Tanner                Syrian Arab Republic
# Marshall-Holloway                         British Virgin Islands
# Matthews Inc                                      Western Sahara
# Nelson-Li                                            Switzerland
# Nichols-James                                   Marshall Islands
# Scott Inc                                               Anguilla
# Taylor-Ramos                                              Kuwait
# Thomas-Spencer                                           Finland
# Wallace, Smith and Shepard                                 Palau
# White, Mcclain and Cobb                                   Poland
#
#                                 Employee_Salary Employment_Status  \
# Company_Name
# Andrade LLC                              850140         Full Time
# Baker, Allen and Edwards                 523499         Full Time
# Bullock-Carrillo                         985290         Full Time
# Campos, Reynolds and Mccormick           516950         Full Time
# James and Sons                           321520         Full Time
# Johnston, Fleming and Tanner             116400         Full Time
# Marshall-Holloway                         58800         Full Time
# Matthews Inc                             777000         Full Time
# Nelson-Li                                796690         Full Time
# Nichols-James                            589090         Full Time
# Scott Inc                                630890         Full Time
# Taylor-Ramos                             870580         Full Time
# Thomas-Spencer                           178570         Full Time
# Wallace, Smith and Shepard               914110         Full Time
# White, Mcclain and Cobb                  656260         Full Time
#
#                                 Employee_Rating
# Company_Name
# Andrade LLC                                 2.6
# Baker, Allen and Edwards                    4.8
# Bullock-Carrillo                            2.4
# Campos, Reynolds and Mccormick              2.3
# James and Sons                              3.9
# Johnston, Fleming and Tanner                3.1
# Marshall-Holloway                           0.6
# Matthews Inc                                3.3
# Nelson-Li                                   4.1
# Nichols-James                               4.3
# Scott Inc                                   3.1
# Taylor-Ramos                                1.3
# Thomas-Spencer                              1.9
# Wallace, Smith and Shepard                  3.2
# White, Mcclain and Cobb                     4.9

# %% [markdown]
# ### 113. Reset the index of the dataframe inplace and delete the older index values.

# %%
df.reset_index(drop=True)
# Out:
#                   Name                  Company_Name  \
# 0       Spencer Adkins                James and Sons
# 1         Julie Morton                 Nichols-James
# 2         Matthew Hall                     Scott Inc
# 3           Brad Scott  Johnston, Fleming and Tanner
# 4        Theresa Owens      Baker, Allen and Edwards
# ...                ...                           ...
# 299995      Nancy Neal              Bullock-Carrillo
# 299996  Michele Butler  Johnston, Fleming and Tanner
# 299997     Lynn Wilson                 Nichols-James
# 299998   Lindsey Keith                 Nichols-James
# 299999   Karen Delgado                James and Sons
#
#                              Employee_Job_Title      Employee_City  \
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299995                              Optometrist  North Melissafurt
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
#
#              Employee_Country  Employee_Salary Employment_Status  \
# 0       Palestinian Territory           321520         Full Time
# 1            Marshall Islands           589090         Full Time
# 2                    Anguilla           630890         Full Time
# 3        Syrian Arab Republic           116400         Full Time
# 4                    Dominica           523499         Full Time
# ...                       ...              ...               ...
# 299995                  Samoa            99670            Intern
# 299996                   Cuba           949580            Intern
# 299997                Bolivia           802830         Full Time
# 299998         Western Sahara           257240         Full Time
# 299999         United Kingdom           575770            Intern
#
#         Employee_Rating
# 0                   3.9
# 1                   4.3
# 2                   3.1
# 3                   3.1
# 4                   4.8
# ...                 ...
# 299995              3.3
# 299996              2.6
# 299997              0.6
# 299998              2.4
# 299999              3.3
#
# [300000 rows x 8 columns]

# %% [markdown]
# ### 115-1) Add a new row at the bottom of the DataFrame.

# %%
new_row = {'Name' : 'Chris Anders', 'Company_Name' : 'Scott Inc',
           'Employee_Job_Title' : 'Production engineer', 'Employee_City' : 'Wardfort',
           'Employee_Country' : 'Anguilla', 'Employee_Salary' : 343930,
           'Employment_Status' : 'Full Time', 'Employee_Rating' : 3.3}

df.append(new_row, ignore_index = True)
# Out:
# <ipython-input-325-4417bb746c1f>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row, ignore_index = True)
#                   Name                  Company_Name  \
# 0       Spencer Adkins                James and Sons
# 1         Julie Morton                 Nichols-James
# 2         Matthew Hall                     Scott Inc
# 3           Brad Scott  Johnston, Fleming and Tanner
# 4        Theresa Owens      Baker, Allen and Edwards
# ...                ...                           ...
# 299996  Michele Butler  Johnston, Fleming and Tanner
# 299997     Lynn Wilson                 Nichols-James
# 299998   Lindsey Keith                 Nichols-James
# 299999   Karen Delgado                James and Sons
# 300000    Chris Anders                     Scott Inc
#
#                              Employee_Job_Title      Employee_City  \
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
# 300000                      Production engineer           Wardfort
#
#              Employee_Country  Employee_Salary Employment_Status  \
# 0       Palestinian Territory           321520         Full Time
# 1            Marshall Islands           589090         Full Time
# 2                    Anguilla           630890         Full Time
# 3        Syrian Arab Republic           116400         Full Time
# 4                    Dominica           523499         Full Time
# ...                       ...              ...               ...
# 299996                   Cuba           949580            Intern
# 299997                Bolivia           802830         Full Time
# 299998         Western Sahara           257240         Full Time
# 299999         United Kingdom           575770            Intern
# 300000               Anguilla           343930         Full Time
#
#         Employee_Rating
# 0                   3.9
# 1                   4.3
# 2                   3.1
# 3                   3.1
# 4                   4.8
# ...                 ...
# 299996              2.6
# 299997              0.6
# 299998              2.4
# 299999              3.3
# 300000              3.3
#
# [300001 rows x 8 columns]

# %% [markdown]
# ### 115-2) Delete the row that was just newly added.

# %%
df.drop(df.index[-1])
# Out:
#                   Name                  Company_Name  \
# 0       Spencer Adkins                James and Sons
# 1         Julie Morton                 Nichols-James
# 2         Matthew Hall                     Scott Inc
# 3           Brad Scott  Johnston, Fleming and Tanner
# 4        Theresa Owens      Baker, Allen and Edwards
# ...                ...                           ...
# 299994   Kelly Bennett       White, Mcclain and Cobb
# 299995      Nancy Neal              Bullock-Carrillo
# 299996  Michele Butler  Johnston, Fleming and Tanner
# 299997     Lynn Wilson                 Nichols-James
# 299998   Lindsey Keith                 Nichols-James
#
#                              Employee_Job_Title      Employee_City  \
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299994                Radiographer, therapeutic           Wardfort
# 299995                              Optometrist  North Melissafurt
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
#
#              Employee_Country  Employee_Salary Employment_Status  \
# 0       Palestinian Territory           321520         Full Time
# 1            Marshall Islands           589090         Full Time
# 2                    Anguilla           630890         Full Time
# 3        Syrian Arab Republic           116400         Full Time
# 4                    Dominica           523499         Full Time
# ...                       ...              ...               ...
# 299994                   Fiji           182270         Full Time
# 299995                  Samoa            99670            Intern
# 299996                   Cuba           949580            Intern
# 299997                Bolivia           802830         Full Time
# 299998         Western Sahara           257240         Full Time
#
#         Employee_Rating
# 0                   3.9
# 1                   4.3
# 2                   3.1
# 3                   3.1
# 4                   4.8
# ...                 ...
# 299994              3.6
# 299995              3.3
# 299996              2.6
# 299997              0.6
# 299998              2.4
#
# [299999 rows x 8 columns]

# %% [markdown]
# ### 117. Add a new column "Employee_Rating_New" which should be as follows:

# %% [markdown]
# Employee_Rating_New = max(1.5, 2*Employee_Rating - 3)

# %%
df['Employee_Rating_New'] = df['Employee_Rating'].apply(lambda x: max(1.5, 2 * x - 3))

# %% [markdown]
# ### 118. Convert the entire DataFrame to a list of lists. Do NOT overwrite to the current dataframe object.

# %%
df_list = df.values.tolist()

# %%
df_list
# Out:
# [['Spencer Adkins',
#   'James and Sons',
#   'Equities trader',
#   'New Russellton',
#   'Palestinian Territory',
#   321520,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Julie Morton',
#   'Nichols-James',
#   'Diplomatic Services operational officer',
#   'North Melissafurt',
#   'Marshall Islands',
#   589090,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Matthew Hall',
#   'Scott Inc',
#   'Regulatory affairs officer',
#   'Wardfort',
#   'Anguilla',
#   630890,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Brad Scott',
#   'Johnston, Fleming and Tanner',
#   'Production engineer',
#   'West Jamesview',
#   'Syrian Arab Republic',
#   116400,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Theresa Owens',
#   'Baker, Allen and Edwards',
#   'Production engineer',
#   'Whiteside',
#   'Dominica',
#   523499,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Vanessa Allen',
#   'Andrade LLC',
#   'Make',
#   'Ricardomouth',
#   'Mali',
#   850140,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Kelly Brown',
#   'Andrade LLC',
#   'Naval architect',
#   'Wardfort',
#   'Aruba',
#   711410,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Vicki Beard',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Western Sahara',
#   777000,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Lisa French',
#   'Taylor-Ramos',
#   'Radiographer, therapeutic',
#   'West Jamesview',
#   'Kuwait',
#   870580,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Michael Edwards',
#   'Campos, Reynolds and Mccormick',
#   'Ergonomist',
#   'New Cindychester',
#   "Lao People's Democratic Republic",
#   516950,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Victoria Sutton',
#   'White, Mcclain and Cobb',
#   'Naval architect',
#   'Whiteside',
#   'Poland',
#   656260,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Timothy Johnson',
#   'Baker, Allen and Edwards',
#   'Regulatory affairs officer',
#   'Ricardomouth',
#   'Georgia',
#   503610,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Tiffany Galvan',
#   'Campos, Reynolds and Mccormick',
#   'Diplomatic Services operational officer',
#   'West Jamesview',
#   'Niger',
#   786430,
#   'Intern',
#   3.6,
#   4.2],
#  ['David Duran',
#   'Nichols-James',
#   'Investment banker, corporate',
#   'New Russellton',
#   'Georgia',
#   910210,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Julie Cook',
#   'Matthews Inc',
#   'Equities trader',
#   'New Russellton',
#   'Puerto Rico',
#   328860,
#   'Full Time',
#   4.8,
#   6.6],
#  ['David Massey',
#   'Johnston, Fleming and Tanner',
#   'Radiographer, therapeutic',
#   'Ricardomouth',
#   'Somalia',
#   581490,
#   'Intern',
#   3.7,
#   4.4],
#  ['Taylor Summers',
#   'Campos, Reynolds and Mccormick',
#   'Naval architect',
#   'North Melissafurt',
#   'Falkland Islands (Malvinas)',
#   280650,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Gail Rose',
#   'Thomas-Spencer',
#   'Patent examiner',
#   'Whitakerbury',
#   'Finland',
#   178570,
#   'Full Time',
#   1.9,
#   1.5],
#  ['Carrie Woods',
#   'Bullock-Carrillo',
#   'Ergonomist',
#   'New Russellton',
#   'Gabon',
#   985290,
#   'Full Time',
#   2.4,
#   1.7999999999999998],
#  ['Christopher Kim',
#   'Thomas-Spencer',
#   'Garment/textile technologist',
#   'New Russellton',
#   'Serbia',
#   242300,
#   'Intern',
#   1.6,
#   1.5],
#  ['Brian Swanson',
#   'Andrade LLC',
#   'Regulatory affairs officer',
#   'Aliciafort',
#   'Libyan Arab Jamahiriya',
#   262670,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Ashley Hess',
#   'Taylor-Ramos',
#   'Investment banker, corporate',
#   'Wardfort',
#   'Netherlands',
#   2990,
#   'Intern',
#   1.5,
#   1.5],
#  ['Carlos Lindsey',
#   'Nichols-James',
#   'Patent examiner',
#   'Kristaburgh',
#   'Jersey',
#   629640,
#   'Intern',
#   0.3,
#   1.5],
#  ['Daniel Medina',
#   'Matthews Inc',
#   'Regulatory affairs officer',
#   'Aliciafort',
#   'Antarctica (the territory South of 60 deg S)',
#   511650,
#   'Intern',
#   3.2,
#   3.4000000000000004],
#  ['Michael Williams',
#   'Johnston, Fleming and Tanner',
#   'Regulatory affairs officer',
#   'Wardfort',
#   'Malawi',
#   705500,
#   'Intern',
#   0.7,
#   1.5],
#  ['David Phillips',
#   'Marshall-Holloway',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'British Virgin Islands',
#   58800,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Donna Rodriguez',
#   'Thomas-Spencer',
#   'Sales promotion account executive',
#   'Whiteside',
#   'Guam',
#   622920,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Courtney Cherry',
#   'Matthews Inc',
#   'Sales promotion account executive',
#   'Wardfort',
#   'Puerto Rico',
#   388970,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Kim Reynolds',
#   'Marshall-Holloway',
#   'Actuary',
#   'West Jamesview',
#   'Faroe Islands',
#   794450,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Rodney Little',
#   'James and Sons',
#   'Armed forces logistics/support/administrative officer',
#   'West Jamesview',
#   'Indonesia',
#   846180,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Melissa Wood',
#   'Thomas-Spencer',
#   'Administrator',
#   'New Russellton',
#   'France',
#   836160,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Antonio Gomez',
#   'Marshall-Holloway',
#   'Radiographer, therapeutic',
#   'Wardfort',
#   'Anguilla',
#   904930,
#   'Intern',
#   1.3,
#   1.5],
#  ['Gary Jackson',
#   'Bullock-Carrillo',
#   'Production engineer',
#   'Aliciafort',
#   'Macedonia',
#   141250,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Selena Moyer',
#   'Baker, Allen and Edwards',
#   'Trading standards officer',
#   'North Melissafurt',
#   'Belize',
#   234370,
#   'Full Time',
#   0.4,
#   1.5],
#  ['Sherry Charles',
#   'Scott Inc',
#   'Garment/textile technologist',
#   'West Jamesview',
#   'El Salvador',
#   787030,
#   'Full Time',
#   0.9,
#   1.5],
#  ['Kevin Flores',
#   'Scott Inc',
#   'Radiographer, therapeutic',
#   'New Cindychester',
#   'Congo',
#   421860,
#   'Full Time',
#   1.3,
#   1.5],
#  ['James Cole',
#   'Campos, Reynolds and Mccormick',
#   'Radiographer, therapeutic',
#   'Wardfort',
#   'Norfolk Island',
#   654770,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Deborah Cantu',
#   'Taylor-Ramos',
#   'Production engineer',
#   'New Russellton',
#   'Kiribati',
#   92600,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Victor Miller',
#   'Thomas-Spencer',
#   'Patent examiner',
#   'New Russellton',
#   'France',
#   560730,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Jessica Reyes',
#   'Thomas-Spencer',
#   'Garment/textile technologist',
#   'Kristaburgh',
#   'Botswana',
#   667490,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Steven Cole',
#   'Marshall-Holloway',
#   'Retail merchandiser',
#   'Kristaburgh',
#   'Nicaragua',
#   981230,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Cassie Murray',
#   'Scott Inc',
#   'Retail merchandiser',
#   'West Jamesview',
#   'Poland',
#   200500,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Nancy Wright',
#   'Johnston, Fleming and Tanner',
#   'Actuary',
#   'Ricardomouth',
#   'Palau',
#   916600,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Hannah Taylor',
#   'Campos, Reynolds and Mccormick',
#   'Ergonomist',
#   'Whiteside',
#   'Western Sahara',
#   251230,
#   'Intern',
#   3.3,
#   3.5999999999999996],
#  ['Kathleen Franco',
#   'Johnston, Fleming and Tanner',
#   'Diplomatic Services operational officer',
#   'Ricardomouth',
#   'Bolivia',
#   185270,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Ronald Clark',
#   'Wallace, Smith and Shepard',
#   'Regulatory affairs officer',
#   'North Melissafurt',
#   'Palau',
#   914110,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['Francis Carter',
#   'Thomas-Spencer',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Singapore',
#   780840,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Jessica Alvarado',
#   'Taylor-Ramos',
#   'Garment/textile technologist',
#   'Whitakerbury',
#   'Greenland',
#   184410,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Shannon Wiggins',
#   'Bullock-Carrillo',
#   'Investment banker, corporate',
#   'Whiteside',
#   'Suriname',
#   880350,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Gerald Santiago',
#   'Thomas-Spencer',
#   'Garment/textile technologist',
#   'Kristaburgh',
#   'El Salvador',
#   873320,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Ralph Taylor',
#   'James and Sons',
#   'Retail merchandiser',
#   'Ricardomouth',
#   'Tuvalu',
#   482270,
#   'Intern',
#   1.9,
#   1.5],
#  ['Katherine Carr',
#   'Baker, Allen and Edwards',
#   'Optometrist',
#   'New Russellton',
#   'Estonia',
#   610870,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Brian Scott',
#   'Thomas-Spencer',
#   'Energy manager',
#   'Ricardomouth',
#   'Portugal',
#   616430,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Robert Kelly',
#   'Wallace, Smith and Shepard',
#   'Diplomatic Services operational officer',
#   'Aliciafort',
#   'Yemen',
#   219120,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Sydney Suarez',
#   'Matthews Inc',
#   'Make',
#   'Aliciafort',
#   'American Samoa',
#   720620,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Amanda Roth',
#   'Taylor-Ramos',
#   'Administrator',
#   'North Melissafurt',
#   'Macedonia',
#   437720,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Gavin Wise',
#   'Marshall-Holloway',
#   'Regulatory affairs officer',
#   'Whiteside',
#   'Netherlands Antilles',
#   624990,
#   'Intern',
#   3.1,
#   3.2],
#  ['Joseph Anderson',
#   'Bullock-Carrillo',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'Bhutan',
#   402290,
#   'Intern',
#   3.3,
#   3.5999999999999996],
#  ['Robert Villanueva',
#   'Bullock-Carrillo',
#   'Make',
#   'North Melissafurt',
#   'Guyana',
#   440700,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Paul Cox',
#   'Thomas-Spencer',
#   'Armed forces logistics/support/administrative officer',
#   'North Melissafurt',
#   'France',
#   598930,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Jessica Stewart',
#   'White, Mcclain and Cobb',
#   'Equities trader',
#   'Whitakerbury',
#   'Kiribati',
#   852150,
#   'Intern',
#   3.9,
#   4.8],
#  ['Micheal Fitzgerald',
#   'Nelson-Li',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Switzerland',
#   796690,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Thomas Wilson',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'Whiteside',
#   'New Caledonia',
#   244960,
#   'Intern',
#   3.4,
#   3.8],
#  ['George Davidson',
#   'Marshall-Holloway',
#   'Optometrist',
#   'New Cindychester',
#   'Zimbabwe',
#   425390,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Nathan Santiago',
#   'Taylor-Ramos',
#   'Administrator',
#   'Aliciafort',
#   'Northern Mariana Islands',
#   587780,
#   'Intern',
#   3.5,
#   4.0],
#  ['Timothy Flores',
#   'White, Mcclain and Cobb',
#   'Garment/textile technologist',
#   'North Melissafurt',
#   'Romania',
#   894970,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Chad Guerrero',
#   'Baker, Allen and Edwards',
#   'Ergonomist',
#   'Aliciafort',
#   'Congo',
#   134810,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Claudia Morrison',
#   'Scott Inc',
#   'Administrator',
#   'Whiteside',
#   'India',
#   470350,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Justin Mclean',
#   'Nelson-Li',
#   'Retail merchandiser',
#   'Wardfort',
#   'Chad',
#   143410,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Jonathan Armstrong',
#   'Scott Inc',
#   'Trading standards officer',
#   'Aliciafort',
#   'San Marino',
#   902300,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Jason Smith',
#   'Scott Inc',
#   'Trading standards officer',
#   'Wardfort',
#   'Mozambique',
#   384980,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Daniel Charles',
#   'White, Mcclain and Cobb',
#   'Actuary',
#   'West Jamesview',
#   'Sierra Leone',
#   536990,
#   'Intern',
#   1.0,
#   1.5],
#  ['Jose Moore',
#   'Bullock-Carrillo',
#   'Diplomatic Services operational officer',
#   'New Cindychester',
#   'Montserrat',
#   684110,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Derrick Spencer',
#   'Nelson-Li',
#   'Sales promotion account executive',
#   'Aliciafort',
#   'Holy See (Vatican City State)',
#   303900,
#   'Full Time',
#   1.5,
#   1.5],
#  ['Robert Humphrey',
#   'Marshall-Holloway',
#   'Patent examiner',
#   'Whiteside',
#   'Togo',
#   190420,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Michelle Estrada',
#   'Thomas-Spencer',
#   'Energy manager',
#   'Ricardomouth',
#   'Saint Pierre and Miquelon',
#   721880,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Michael Conway',
#   'Nichols-James',
#   'Radiographer, therapeutic',
#   'Wardfort',
#   'Bangladesh',
#   187720,
#   'Full Time',
#   0.1,
#   1.5],
#  ['Lori Smith',
#   'Thomas-Spencer',
#   'Optometrist',
#   'New Cindychester',
#   'Venezuela',
#   687310,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Timothy Ramos',
#   'Nelson-Li',
#   'Equities trader',
#   'West Jamesview',
#   'Congo',
#   219690,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Bradley Montgomery',
#   'Wallace, Smith and Shepard',
#   'Regulatory affairs officer',
#   'Whiteside',
#   'Iraq',
#   90650,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Jonathan Howell',
#   'Nichols-James',
#   'Armed forces logistics/support/administrative officer',
#   'Whitakerbury',
#   'Aruba',
#   711330,
#   'Full Time',
#   3.6,
#   4.2],
#  ['William Hughes',
#   'Nichols-James',
#   'Administrator',
#   'New Cindychester',
#   'Belarus',
#   16340,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Steven Costa',
#   'Taylor-Ramos',
#   'Energy manager',
#   'Wardfort',
#   'Albania',
#   314470,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Nancy Stephens',
#   'Johnston, Fleming and Tanner',
#   'Ergonomist',
#   'Kristaburgh',
#   'Taiwan',
#   430620,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Lauren Barton',
#   'Baker, Allen and Edwards',
#   'Make',
#   'New Cindychester',
#   'Pakistan',
#   789140,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Dawn Lewis',
#   'Campos, Reynolds and Mccormick',
#   'Optometrist',
#   'Whitakerbury',
#   'Suriname',
#   270840,
#   'Intern',
#   2.2,
#   1.5],
#  ['Wanda Jones',
#   'White, Mcclain and Cobb',
#   'Regulatory affairs officer',
#   'Kristaburgh',
#   'Libyan Arab Jamahiriya',
#   848140,
#   'Intern',
#   0.2,
#   1.5],
#  ['Brittany Graham',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Ethiopia',
#   123700,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Julie Richard',
#   'Bullock-Carrillo',
#   'Naval architect',
#   'Wardfort',
#   'Burundi',
#   222850,
#   'Full Time',
#   4.6,
#   6.199999999999999],
#  ['Janet Bridges',
#   'Thomas-Spencer',
#   'Optometrist',
#   'Whitakerbury',
#   'Wallis and Futuna',
#   745150,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Willie Anderson',
#   'Andrade LLC',
#   'Garment/textile technologist',
#   'Kristaburgh',
#   'Tuvalu',
#   268320,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Diamond Kent',
#   'Wallace, Smith and Shepard',
#   'Radiographer, therapeutic',
#   'Aliciafort',
#   'Zambia',
#   538290,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Kevin Miller',
#   'Bullock-Carrillo',
#   'Investment banker, corporate',
#   'New Russellton',
#   'Saint Pierre and Miquelon',
#   493800,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Sierra Brewer',
#   'Thomas-Spencer',
#   'Naval architect',
#   'New Russellton',
#   'Saint Pierre and Miquelon',
#   127940,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Natasha Harmon',
#   'Matthews Inc',
#   'Radiographer, therapeutic',
#   'West Jamesview',
#   'Bolivia',
#   790000,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Angela Stone',
#   'Wallace, Smith and Shepard',
#   'Actuary',
#   'New Russellton',
#   'Switzerland',
#   313250,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Anthony Weiss',
#   'Scott Inc',
#   'Armed forces logistics/support/administrative officer',
#   'West Jamesview',
#   'Guatemala',
#   356220,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Renee Benson',
#   'Thomas-Spencer',
#   'Investment banker, corporate',
#   'Wardfort',
#   'Thailand',
#   171820,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Elizabeth Clements',
#   'Taylor-Ramos',
#   'Administrator',
#   'Whiteside',
#   'Mauritania',
#   827360,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Jeanette Wang',
#   'Baker, Allen and Edwards',
#   'Actuary',
#   'Whiteside',
#   'New Zealand',
#   339100,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Tracy Maxwell',
#   'Matthews Inc',
#   'Sales promotion account executive',
#   'New Russellton',
#   'Oman',
#   742410,
#   'Full Time',
#   0.5,
#   1.5],
#  ['James Alvarez',
#   'Bullock-Carrillo',
#   'Equities trader',
#   'Kristaburgh',
#   'Grenada',
#   220440,
#   'Intern',
#   2.1,
#   1.5],
#  ['Stacy Smith',
#   'Bullock-Carrillo',
#   'Patent examiner',
#   'Kristaburgh',
#   'Israel',
#   666680,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Jennifer Daniels',
#   'White, Mcclain and Cobb',
#   'Equities trader',
#   'West Jamesview',
#   'Congo',
#   130740,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Jose Thompson',
#   'Scott Inc',
#   'Actuary',
#   'Whitakerbury',
#   'Sweden',
#   121110,
#   'Intern',
#   1.2,
#   1.5],
#  ['Mary Bailey',
#   'Baker, Allen and Edwards',
#   'Diplomatic Services operational officer',
#   'Wardfort',
#   'Sierra Leone',
#   142620,
#   'Intern',
#   0.8,
#   1.5],
#  ['Susan Moses',
#   'Johnston, Fleming and Tanner',
#   'Make',
#   'Aliciafort',
#   "Cote d'Ivoire",
#   196070,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Kathryn Sweeney',
#   'Campos, Reynolds and Mccormick',
#   'Make',
#   'New Russellton',
#   'Madagascar',
#   489190,
#   'Intern',
#   0.3,
#   1.5],
#  ['Frank Torres',
#   'Campos, Reynolds and Mccormick',
#   'Trading standards officer',
#   'Whitakerbury',
#   'Sierra Leone',
#   693190,
#   'Intern',
#   2.9,
#   2.8],
#  ['James Wright',
#   'Wallace, Smith and Shepard',
#   'Energy manager',
#   'Ricardomouth',
#   'Chad',
#   79790,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Donald Nelson',
#   'Campos, Reynolds and Mccormick',
#   'Trading standards officer',
#   'West Jamesview',
#   'Estonia',
#   37280,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Daniel Adams',
#   'Bullock-Carrillo',
#   'Investment banker, corporate',
#   'New Cindychester',
#   'San Marino',
#   339250,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Crystal Brown',
#   'Johnston, Fleming and Tanner',
#   'Garment/textile technologist',
#   'Whitakerbury',
#   'Romania',
#   919880,
#   'Full Time',
#   4.5,
#   6.0],
#  ['Judy Roberts',
#   'Campos, Reynolds and Mccormick',
#   'Ergonomist',
#   'Whitakerbury',
#   'Northern Mariana Islands',
#   45560,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Jeremiah Kelly',
#   'Scott Inc',
#   'Make',
#   'West Jamesview',
#   'Anguilla',
#   155360,
#   'Intern',
#   4.9,
#   6.800000000000001],
#  ['Gary Hernandez',
#   'Taylor-Ramos',
#   'Radiographer, therapeutic',
#   'New Russellton',
#   'Solomon Islands',
#   888730,
#   'Intern',
#   2.5,
#   2.0],
#  ['Annette Saunders',
#   'Marshall-Holloway',
#   'Ergonomist',
#   'New Cindychester',
#   'Monaco',
#   684380,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Jacob Cunningham',
#   'James and Sons',
#   'Patent examiner',
#   'Aliciafort',
#   'Latvia',
#   876760,
#   'Intern',
#   3.8,
#   4.6],
#  ['Stacey Ellison',
#   'Baker, Allen and Edwards',
#   'Radiographer, therapeutic',
#   'West Jamesview',
#   'Hungary',
#   393820,
#   'Full Time',
#   3.5,
#   4.0],
#  ['Jason Parrish',
#   'Andrade LLC',
#   'Garment/textile technologist',
#   'Aliciafort',
#   "Cote d'Ivoire",
#   581130,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Pamela Martinez',
#   'James and Sons',
#   'Garment/textile technologist',
#   'Whiteside',
#   'Dominican Republic',
#   587360,
#   'Intern',
#   3.6,
#   4.2],
#  ['Christine Harrison',
#   'James and Sons',
#   'Trading standards officer',
#   'West Jamesview',
#   'Namibia',
#   684820,
#   'Intern',
#   1.1,
#   1.5],
#  ['Joanna Mclean',
#   'Andrade LLC',
#   'Actuary',
#   'North Melissafurt',
#   'Kuwait',
#   108980,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Kyle Rogers',
#   'Baker, Allen and Edwards',
#   'Patent examiner',
#   'Whitakerbury',
#   'Tuvalu',
#   931250,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Joshua Huffman',
#   'James and Sons',
#   'Garment/textile technologist',
#   'New Russellton',
#   'Cook Islands',
#   694760,
#   'Full Time',
#   5.0,
#   7.0],
#  ['Michael Gonzalez',
#   'Bullock-Carrillo',
#   'Naval architect',
#   'West Jamesview',
#   'Sweden',
#   302110,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Michael Morgan',
#   'Wallace, Smith and Shepard',
#   'Investment banker, corporate',
#   'Wardfort',
#   'Saint Kitts and Nevis',
#   178380,
#   'Full Time',
#   0.4,
#   1.5],
#  ['Matthew Wright',
#   'Bullock-Carrillo',
#   'Energy manager',
#   'Whiteside',
#   'El Salvador',
#   626340,
#   'Intern',
#   2.3,
#   1.5999999999999996],
#  ['Courtney Schneider',
#   'Nichols-James',
#   'Regulatory affairs officer',
#   'Whitakerbury',
#   'Sri Lanka',
#   750440,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Connie Coleman',
#   'Andrade LLC',
#   'Optometrist',
#   'Kristaburgh',
#   'Indonesia',
#   899260,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Brandon Casey',
#   'Wallace, Smith and Shepard',
#   'Make',
#   'New Cindychester',
#   'Sudan',
#   590560,
#   'Intern',
#   0.1,
#   1.5],
#  ['Tina Jenkins',
#   'Scott Inc',
#   'Investment banker, corporate',
#   'North Melissafurt',
#   'Malaysia',
#   100420,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Trevor Wilson',
#   'Baker, Allen and Edwards',
#   'Optometrist',
#   'Aliciafort',
#   'Andorra',
#   661420,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Morgan Shaw',
#   'Matthews Inc',
#   'Patent examiner',
#   'Whiteside',
#   'Egypt',
#   523320,
#   'Intern',
#   3.3,
#   3.5999999999999996],
#  ['Angela Hatfield',
#   'Campos, Reynolds and Mccormick',
#   'Regulatory affairs officer',
#   'Wardfort',
#   'Turkey',
#   989380,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Alicia Bell',
#   'Wallace, Smith and Shepard',
#   'Investment banker, corporate',
#   'Whitakerbury',
#   'Martinique',
#   832520,
#   'Intern',
#   2.5,
#   2.0],
#  ['Victor Sandoval',
#   'Taylor-Ramos',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   "Cote d'Ivoire",
#   819610,
#   'Intern',
#   0.5,
#   1.5],
#  ['Jennifer Smith',
#   'Baker, Allen and Edwards',
#   'Diplomatic Services operational officer',
#   'New Cindychester',
#   'Cuba',
#   202010,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['Matthew Perez',
#   'White, Mcclain and Cobb',
#   'Optometrist',
#   'New Russellton',
#   'Western Sahara',
#   711310,
#   'Intern',
#   4.4,
#   5.800000000000001],
#  ['Michael Garcia',
#   'James and Sons',
#   'Equities trader',
#   'Kristaburgh',
#   'Lithuania',
#   729250,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Joseph Johnson',
#   'Baker, Allen and Edwards',
#   'Optometrist',
#   'Whitakerbury',
#   'France',
#   993550,
#   'Full Time',
#   1.9,
#   1.5],
#  ['Stephen Alvarado',
#   'Matthews Inc',
#   'Sales promotion account executive',
#   'New Cindychester',
#   'Syrian Arab Republic',
#   462080,
#   'Intern',
#   0.5,
#   1.5],
#  ['Michaela Hawkins',
#   'Johnston, Fleming and Tanner',
#   'Armed forces logistics/support/administrative officer',
#   'Whitakerbury',
#   'Greenland',
#   676440,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Sabrina Salinas',
#   'Nichols-James',
#   'Optometrist',
#   'West Jamesview',
#   'Luxembourg',
#   704190,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Linda Kelley',
#   'Campos, Reynolds and Mccormick',
#   'Make',
#   'Whitakerbury',
#   'Belarus',
#   202350,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Shelby Moore',
#   'Bullock-Carrillo',
#   'Retail merchandiser',
#   'Wardfort',
#   'Nauru',
#   250210,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Christopher Le',
#   'Taylor-Ramos',
#   'Equities trader',
#   'North Melissafurt',
#   'Djibouti',
#   647170,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Raymond Nguyen',
#   'Bullock-Carrillo',
#   'Trading standards officer',
#   'West Jamesview',
#   'Fiji',
#   565500,
#   'Intern',
#   1.4,
#   1.5],
#  ['Christopher Gibson',
#   'Wallace, Smith and Shepard',
#   'Administrator',
#   'Whitakerbury',
#   'Cayman Islands',
#   754000,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Jeremy Miller',
#   'Thomas-Spencer',
#   'Armed forces logistics/support/administrative officer',
#   'West Jamesview',
#   'Norfolk Island',
#   744430,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Kristina Rose',
#   'James and Sons',
#   'Actuary',
#   'Ricardomouth',
#   'Nicaragua',
#   46190,
#   'Intern',
#   1.4,
#   1.5],
#  ['Allison Mclaughlin',
#   'Andrade LLC',
#   'Sales promotion account executive',
#   'Aliciafort',
#   'Honduras',
#   740640,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Dylan Davenport',
#   'Nichols-James',
#   'Equities trader',
#   'Whitakerbury',
#   'Cambodia',
#   136500,
#   'Full Time',
#   1.7,
#   1.5],
#  ['Charles Maynard',
#   'Matthews Inc',
#   'Administrator',
#   'Whiteside',
#   'Martinique',
#   287280,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Morgan Davis',
#   'Thomas-Spencer',
#   'Actuary',
#   'Whiteside',
#   'San Marino',
#   823660,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['Sandra Mitchell',
#   'White, Mcclain and Cobb',
#   'Equities trader',
#   'West Jamesview',
#   'Equatorial Guinea',
#   940480,
#   'Intern',
#   4.3,
#   5.6],
#  ['Devin Crawford',
#   'Andrade LLC',
#   'Regulatory affairs officer',
#   'North Melissafurt',
#   'Somalia',
#   598860,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Christina Carlson',
#   'Bullock-Carrillo',
#   'Radiographer, therapeutic',
#   'West Jamesview',
#   'Slovakia (Slovak Republic)',
#   679520,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Randy Brown',
#   'Nelson-Li',
#   'Equities trader',
#   'Aliciafort',
#   'Uzbekistan',
#   121970,
#   'Full Time',
#   4.5,
#   6.0],
#  ['Maria Mayo',
#   'Johnston, Fleming and Tanner',
#   'Energy manager',
#   'Whiteside',
#   'Iceland',
#   225490,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Marcus Hall',
#   'Wallace, Smith and Shepard',
#   'Garment/textile technologist',
#   'New Russellton',
#   'Greenland',
#   214970,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Carl Trevino',
#   'Nichols-James',
#   'Actuary',
#   'Whitakerbury',
#   'Paraguay',
#   257350,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Nicole Wilkins',
#   'Andrade LLC',
#   'Ergonomist',
#   'Whitakerbury',
#   'Namibia',
#   975090,
#   'Full Time',
#   1.7,
#   1.5],
#  ['James Cox',
#   'Scott Inc',
#   'Production engineer',
#   'North Melissafurt',
#   'Afghanistan',
#   63280,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Michael Cooper',
#   'Matthews Inc',
#   'Energy manager',
#   'Kristaburgh',
#   'Ecuador',
#   553230,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Michelle Hoffman',
#   'Taylor-Ramos',
#   'Regulatory affairs officer',
#   'West Jamesview',
#   'Chad',
#   480420,
#   'Full Time',
#   4.6,
#   6.199999999999999],
#  ['Allen Grant',
#   'Taylor-Ramos',
#   'Investment banker, corporate',
#   'Kristaburgh',
#   'Saint Vincent and the Grenadines',
#   475820,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Amanda Arnold',
#   'Nelson-Li',
#   'Investment banker, corporate',
#   'Wardfort',
#   'Congo',
#   43810,
#   'Full Time',
#   4.0,
#   5.0],
#  ['Jennifer Olson',
#   'Wallace, Smith and Shepard',
#   'Diplomatic Services operational officer',
#   'New Russellton',
#   'Thailand',
#   707060,
#   'Intern',
#   4.0,
#   5.0],
#  ['Thomas Cooper',
#   'James and Sons',
#   'Regulatory affairs officer',
#   'West Jamesview',
#   'Germany',
#   877980,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Derek Galloway',
#   'Bullock-Carrillo',
#   'Garment/textile technologist',
#   'Whitakerbury',
#   'French Guiana',
#   697400,
#   'Intern',
#   1.7,
#   1.5],
#  ['Ryan Crawford',
#   'White, Mcclain and Cobb',
#   'Sales promotion account executive',
#   'Aliciafort',
#   'Togo',
#   39400,
#   'Full Time',
#   0.3,
#   1.5],
#  ['Jeremy Taylor',
#   'Nelson-Li',
#   'Regulatory affairs officer',
#   'New Cindychester',
#   'Botswana',
#   637930,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Phillip Stanton',
#   'Nelson-Li',
#   'Equities trader',
#   'New Cindychester',
#   'Luxembourg',
#   769840,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Sarah Bryan',
#   'Marshall-Holloway',
#   'Trading standards officer',
#   'Whiteside',
#   'Dominica',
#   117300,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Emily Ayala',
#   'Andrade LLC',
#   'Sales promotion account executive',
#   'Ricardomouth',
#   'Czech Republic',
#   963680,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Emma Garcia',
#   'Baker, Allen and Edwards',
#   'Naval architect',
#   'New Cindychester',
#   'Ethiopia',
#   958130,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Lauren Thompson',
#   'Matthews Inc',
#   'Patent examiner',
#   'New Cindychester',
#   'American Samoa',
#   584900,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Tiffany Gross',
#   'Scott Inc',
#   'Optometrist',
#   'Aliciafort',
#   'Korea',
#   836110,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Tyler Nash',
#   'Campos, Reynolds and Mccormick',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'San Marino',
#   471940,
#   'Full Time',
#   0.3,
#   1.5],
#  ['Shelby Brown',
#   'Marshall-Holloway',
#   'Equities trader',
#   'New Cindychester',
#   'Vanuatu',
#   957080,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Michael Snyder',
#   'James and Sons',
#   'Investment banker, corporate',
#   'North Melissafurt',
#   'Syrian Arab Republic',
#   465280,
#   'Intern',
#   4.5,
#   6.0],
#  ['Michael Gardner',
#   'Bullock-Carrillo',
#   'Naval architect',
#   'Wardfort',
#   'Sweden',
#   78620,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Pamela Romero',
#   'Andrade LLC',
#   'Trading standards officer',
#   'Wardfort',
#   'Northern Mariana Islands',
#   828810,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Sonya Davis',
#   'Baker, Allen and Edwards',
#   'Armed forces logistics/support/administrative officer',
#   'Kristaburgh',
#   'Marshall Islands',
#   512499,
#   'Full Time',
#   3.0,
#   3.0],
#  ['Emma Kim',
#   'Marshall-Holloway',
#   'Optometrist',
#   'New Cindychester',
#   "Cote d'Ivoire",
#   85940,
#   'Full Time',
#   1.6,
#   1.5],
#  ['Victoria Anthony',
#   'Campos, Reynolds and Mccormick',
#   'Administrator',
#   'Wardfort',
#   'Iceland',
#   856940,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Pamela Howard',
#   'Campos, Reynolds and Mccormick',
#   'Retail merchandiser',
#   'West Jamesview',
#   'Azerbaijan',
#   251740,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Ann White',
#   'Scott Inc',
#   'Ergonomist',
#   'North Melissafurt',
#   'Estonia',
#   724860,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Christine Campos',
#   'White, Mcclain and Cobb',
#   'Radiographer, therapeutic',
#   'Whiteside',
#   'Albania',
#   524610,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Brandi Zimmerman',
#   'White, Mcclain and Cobb',
#   'Diplomatic Services operational officer',
#   'New Russellton',
#   'Wallis and Futuna',
#   38580,
#   'Intern',
#   0.9,
#   1.5],
#  ['Michael Anderson',
#   'White, Mcclain and Cobb',
#   'Energy manager',
#   'New Russellton',
#   'Turks and Caicos Islands',
#   595060,
#   'Intern',
#   2.0,
#   1.5],
#  ['Kevin Mclaughlin',
#   'Andrade LLC',
#   'Ergonomist',
#   'Kristaburgh',
#   'Korea',
#   332390,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Tanya Martinez',
#   'Nelson-Li',
#   'Retail merchandiser',
#   'Whiteside',
#   'Czech Republic',
#   641330,
#   'Full Time',
#   1.4,
#   1.5],
#  ['David Marquez',
#   'Baker, Allen and Edwards',
#   'Diplomatic Services operational officer',
#   'New Cindychester',
#   'Falkland Islands (Malvinas)',
#   687990,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Ebony Trujillo',
#   'James and Sons',
#   'Armed forces logistics/support/administrative officer',
#   'North Melissafurt',
#   'Ireland',
#   821840,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Shawn Shannon',
#   'Nelson-Li',
#   'Radiographer, therapeutic',
#   'Whitakerbury',
#   'Chad',
#   799690,
#   'Intern',
#   1.8,
#   1.5],
#  ['David Moore',
#   'Thomas-Spencer',
#   'Retail merchandiser',
#   'West Jamesview',
#   'Macao',
#   886260,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Heather Thomas',
#   'Campos, Reynolds and Mccormick',
#   'Retail merchandiser',
#   'Whiteside',
#   'Andorra',
#   294910,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Amy Tran',
#   'Thomas-Spencer',
#   'Actuary',
#   'Whiteside',
#   'Kiribati',
#   248130,
#   'Full Time',
#   4.0,
#   5.0],
#  ['Keith Reid',
#   'Wallace, Smith and Shepard',
#   'Patent examiner',
#   'Whitakerbury',
#   'Romania',
#   343350,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Emily Smith',
#   'Taylor-Ramos',
#   'Garment/textile technologist',
#   'New Russellton',
#   'Netherlands Antilles',
#   827800,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Pamela Dawson',
#   'Nelson-Li',
#   'Patent examiner',
#   'Kristaburgh',
#   'Hong Kong',
#   117470,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Tony Brown',
#   'James and Sons',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'Holy See (Vatican City State)',
#   563840,
#   'Full Time',
#   4.5,
#   6.0],
#  ['Jeffery Braun',
#   'Bullock-Carrillo',
#   'Patent examiner',
#   'West Jamesview',
#   'Hong Kong',
#   180230,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Alexander Anderson',
#   'Bullock-Carrillo',
#   'Investment banker, corporate',
#   'Whitakerbury',
#   'Wallis and Futuna',
#   820170,
#   'Intern',
#   1.0,
#   1.5],
#  ['Nicole Johnson',
#   'Campos, Reynolds and Mccormick',
#   'Diplomatic Services operational officer',
#   'North Melissafurt',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   568800,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Jeanne Smith',
#   'Marshall-Holloway',
#   'Energy manager',
#   'Kristaburgh',
#   'Bangladesh',
#   803770,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Roberto Kerr',
#   'Campos, Reynolds and Mccormick',
#   'Ergonomist',
#   'West Jamesview',
#   'Senegal',
#   857900,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Amy Parker',
#   'Johnston, Fleming and Tanner',
#   'Production engineer',
#   'Whiteside',
#   'Guyana',
#   777190,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Michael Johnston',
#   'Johnston, Fleming and Tanner',
#   'Trading standards officer',
#   'North Melissafurt',
#   'Reunion',
#   257540,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Mark Johnson',
#   'Johnston, Fleming and Tanner',
#   'Sales promotion account executive',
#   'New Cindychester',
#   'Mauritania',
#   235590,
#   'Full Time',
#   0.9,
#   1.5],
#  ['Crystal Adams',
#   'Johnston, Fleming and Tanner',
#   'Investment banker, corporate',
#   'Wardfort',
#   'Senegal',
#   47350,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Anthony Short',
#   'Thomas-Spencer',
#   'Administrator',
#   'New Cindychester',
#   'Guinea',
#   454450,
#   'Full Time',
#   2.5,
#   2.0],
#  ['David Arias',
#   'Andrade LLC',
#   'Optometrist',
#   'Aliciafort',
#   'Sudan',
#   628270,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Kristen Hill',
#   'Nelson-Li',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'Andorra',
#   725010,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Gregory Ford',
#   'Wallace, Smith and Shepard',
#   'Patent examiner',
#   'Aliciafort',
#   'Mexico',
#   570460,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Rachel Harrison',
#   'Johnston, Fleming and Tanner',
#   'Patent examiner',
#   'Wardfort',
#   'United Arab Emirates',
#   882730,
#   'Intern',
#   1.1,
#   1.5],
#  ['Noah Williams',
#   'Wallace, Smith and Shepard',
#   'Regulatory affairs officer',
#   'Kristaburgh',
#   'Azerbaijan',
#   864450,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Donna Hill',
#   'Marshall-Holloway',
#   'Make',
#   'North Melissafurt',
#   'Greece',
#   640870,
#   'Full Time',
#   4.6,
#   6.199999999999999],
#  ['Emily Navarro',
#   'White, Mcclain and Cobb',
#   'Garment/textile technologist',
#   'West Jamesview',
#   'Timor-Leste',
#   930370,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Alexander Scott',
#   'Matthews Inc',
#   'Sales promotion account executive',
#   'Ricardomouth',
#   'American Samoa',
#   184700,
#   'Full Time',
#   0.5,
#   1.5],
#  ['William Dunn',
#   'Johnston, Fleming and Tanner',
#   'Regulatory affairs officer',
#   'Aliciafort',
#   'Georgia',
#   646430,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Robert Marshall',
#   'Scott Inc',
#   'Ergonomist',
#   'Kristaburgh',
#   'Saint Lucia',
#   925120,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Brian Thomas',
#   'Andrade LLC',
#   'Armed forces logistics/support/administrative officer',
#   'North Melissafurt',
#   'Sao Tome and Principe',
#   28890,
#   'Intern',
#   2.4,
#   1.7999999999999998],
#  ['Christopher Wilson',
#   'Thomas-Spencer',
#   'Administrator',
#   'Whiteside',
#   'Japan',
#   838480,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Brian Moore',
#   'Johnston, Fleming and Tanner',
#   'Trading standards officer',
#   'Kristaburgh',
#   'Philippines',
#   270580,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Jackie Arnold',
#   'Baker, Allen and Edwards',
#   'Patent examiner',
#   'North Melissafurt',
#   'Chad',
#   85920,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Benjamin Holt',
#   'Nelson-Li',
#   'Actuary',
#   'New Russellton',
#   'Saint Martin',
#   508399,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Michael Spencer',
#   'Scott Inc',
#   'Optometrist',
#   'Ricardomouth',
#   'Argentina',
#   915190,
#   'Intern',
#   2.3,
#   1.5999999999999996],
#  ['Justin Richards',
#   'Matthews Inc',
#   'Radiographer, therapeutic',
#   'New Russellton',
#   'Guyana',
#   126690,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Danny Marsh',
#   'Andrade LLC',
#   'Administrator',
#   'New Russellton',
#   'Rwanda',
#   7280,
#   'Intern',
#   4.0,
#   5.0],
#  ['Tonya Rivera',
#   'Baker, Allen and Edwards',
#   'Retail merchandiser',
#   'North Melissafurt',
#   'Ethiopia',
#   106810,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Dalton Douglas',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'New Russellton',
#   'Jordan',
#   126179,
#   'Full Time',
#   0.5,
#   1.5],
#  ['Carrie Watts',
#   'Taylor-Ramos',
#   'Retail merchandiser',
#   'Ricardomouth',
#   'Suriname',
#   199530,
#   'Intern',
#   0.7,
#   1.5],
#  ['Matthew Crane',
#   'James and Sons',
#   'Actuary',
#   'North Melissafurt',
#   'Saint Kitts and Nevis',
#   595440,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Nathan Wright',
#   'Scott Inc',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Slovakia (Slovak Republic)',
#   733110,
#   'Intern',
#   4.6,
#   6.199999999999999],
#  ['Kevin Williams',
#   'Taylor-Ramos',
#   'Investment banker, corporate',
#   'Kristaburgh',
#   'Pitcairn Islands',
#   942600,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Wendy Irwin',
#   'Thomas-Spencer',
#   'Radiographer, therapeutic',
#   'New Cindychester',
#   'Poland',
#   716700,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Teresa Reyes',
#   'Matthews Inc',
#   'Armed forces logistics/support/administrative officer',
#   'Wardfort',
#   'Dominica',
#   471310,
#   'Intern',
#   3.8,
#   4.6],
#  ['Ashley Lewis',
#   'Taylor-Ramos',
#   'Make',
#   'Ricardomouth',
#   'Tanzania',
#   541660,
#   'Intern',
#   3.3,
#   3.5999999999999996],
#  ['Stephanie Bernard',
#   'Thomas-Spencer',
#   'Administrator',
#   'Aliciafort',
#   'Sri Lanka',
#   992230,
#   'Intern',
#   4.5,
#   6.0],
#  ['Jared Miranda',
#   'James and Sons',
#   'Actuary',
#   'New Cindychester',
#   'Argentina',
#   890310,
#   'Full Time',
#   0.4,
#   1.5],
#  ['David Collins',
#   'Andrade LLC',
#   'Ergonomist',
#   'Kristaburgh',
#   'Guyana',
#   226310,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['Stuart Olson',
#   'James and Sons',
#   'Trading standards officer',
#   'Wardfort',
#   'Pitcairn Islands',
#   928390,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Lisa Wang',
#   'Scott Inc',
#   'Trading standards officer',
#   'Wardfort',
#   'Equatorial Guinea',
#   611000,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Lee Becker',
#   'Scott Inc',
#   'Equities trader',
#   'Aliciafort',
#   'Peru',
#   111460,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Travis Davis',
#   'Johnston, Fleming and Tanner',
#   'Investment banker, corporate',
#   'Ricardomouth',
#   'Solomon Islands',
#   790700,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Cody Carlson',
#   'Campos, Reynolds and Mccormick',
#   'Radiographer, therapeutic',
#   'Ricardomouth',
#   'Kenya',
#   919210,
#   'Intern',
#   1.8,
#   1.5],
#  ['Michael Larsen',
#   'Matthews Inc',
#   'Patent examiner',
#   'New Russellton',
#   'Vanuatu',
#   639300,
#   'Full Time',
#   1.7,
#   1.5],
#  ['Steven Rodriguez',
#   'Baker, Allen and Edwards',
#   'Investment banker, corporate',
#   'New Russellton',
#   'South Georgia and the South Sandwich Islands',
#   841630,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Joshua Garrett',
#   'Scott Inc',
#   'Ergonomist',
#   'Aliciafort',
#   'Bosnia and Herzegovina',
#   958860,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Jessica Curtis',
#   'Marshall-Holloway',
#   'Radiographer, therapeutic',
#   'North Melissafurt',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   769760,
#   'Intern',
#   2.3,
#   1.5999999999999996],
#  ['Laura Walker',
#   'Scott Inc',
#   'Diplomatic Services operational officer',
#   'West Jamesview',
#   'Liechtenstein',
#   822040,
#   'Intern',
#   4.8,
#   6.6],
#  ['Megan Guerrero',
#   'Marshall-Holloway',
#   'Garment/textile technologist',
#   'Whiteside',
#   'Saint Vincent and the Grenadines',
#   706430,
#   'Full Time',
#   0.4,
#   1.5],
#  ['Daniel Wood',
#   'Campos, Reynolds and Mccormick',
#   'Actuary',
#   'Ricardomouth',
#   'Romania',
#   735880,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Melissa Olson',
#   'Marshall-Holloway',
#   'Armed forces logistics/support/administrative officer',
#   'West Jamesview',
#   'Mexico',
#   705050,
#   'Full Time',
#   1.9,
#   1.5],
#  ['Emily Johnson',
#   'Matthews Inc',
#   'Radiographer, therapeutic',
#   'West Jamesview',
#   'Isle of Man',
#   251479,
#   'Intern',
#   0.2,
#   1.5],
#  ['Brett Gray',
#   'Johnston, Fleming and Tanner',
#   'Optometrist',
#   'West Jamesview',
#   'Ghana',
#   536340,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Jeffrey Cardenas',
#   'Johnston, Fleming and Tanner',
#   'Patent examiner',
#   'Whitakerbury',
#   'Central African Republic',
#   237470,
#   'Full Time',
#   0.4,
#   1.5],
#  ['Shane Martinez',
#   'Andrade LLC',
#   'Make',
#   'New Cindychester',
#   'Martinique',
#   118680,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Margaret Vaughn',
#   'Bullock-Carrillo',
#   'Make',
#   'New Russellton',
#   "Lao People's Democratic Republic",
#   517970,
#   'Full Time',
#   1.6,
#   1.5],
#  ['Johnathan Russell',
#   'Scott Inc',
#   'Naval architect',
#   'Whitakerbury',
#   'Algeria',
#   118760,
#   'Full Time',
#   0.9,
#   1.5],
#  ['Alexander Gonzales',
#   'James and Sons',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Bahrain',
#   449700,
#   'Intern',
#   1.4,
#   1.5],
#  ['Veronica Howard',
#   'Thomas-Spencer',
#   'Actuary',
#   'North Melissafurt',
#   'Iceland',
#   662260,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Brian Williams',
#   'Bullock-Carrillo',
#   'Production engineer',
#   'Kristaburgh',
#   'Dominican Republic',
#   950960,
#   'Full Time',
#   3.0,
#   3.0],
#  ['John Thomas',
#   'Nichols-James',
#   'Investment banker, corporate',
#   'North Melissafurt',
#   'French Polynesia',
#   458070,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Jamie Ramirez',
#   'Matthews Inc',
#   'Radiographer, therapeutic',
#   'New Russellton',
#   'Samoa',
#   760910,
#   'Intern',
#   2.8,
#   2.5999999999999996],
#  ['Gabriel Spencer',
#   'Johnston, Fleming and Tanner',
#   'Diplomatic Services operational officer',
#   'Aliciafort',
#   'Saint Vincent and the Grenadines',
#   832880,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Kristen Newman',
#   'Matthews Inc',
#   'Regulatory affairs officer',
#   'North Melissafurt',
#   'Poland',
#   125190,
#   'Intern',
#   0.9,
#   1.5],
#  ['Lisa Hunter',
#   'Johnston, Fleming and Tanner',
#   'Optometrist',
#   'Aliciafort',
#   'Svalbard & Jan Mayen Islands',
#   815100,
#   'Full Time',
#   4.5,
#   6.0],
#  ['Andrew Martin',
#   'Baker, Allen and Edwards',
#   'Diplomatic Services operational officer',
#   'Whiteside',
#   'Hungary',
#   784000,
#   'Intern',
#   2.6,
#   2.2],
#  ['William Aguilar',
#   'Wallace, Smith and Shepard',
#   'Optometrist',
#   'New Russellton',
#   'French Polynesia',
#   467900,
#   'Intern',
#   1.2,
#   1.5],
#  ['David Harper',
#   'Thomas-Spencer',
#   'Trading standards officer',
#   'Kristaburgh',
#   'Sri Lanka',
#   211370,
#   'Full Time',
#   1.7,
#   1.5],
#  ['Janice Jennings',
#   'Campos, Reynolds and Mccormick',
#   'Make',
#   'Kristaburgh',
#   'Dominican Republic',
#   266830,
#   'Full Time',
#   1.7,
#   1.5],
#  ['Jennifer Howe',
#   'Baker, Allen and Edwards',
#   'Radiographer, therapeutic',
#   'North Melissafurt',
#   'Bangladesh',
#   741960,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Donna Robinson',
#   'Andrade LLC',
#   'Sales promotion account executive',
#   'Ricardomouth',
#   "Lao People's Democratic Republic",
#   194650,
#   'Full Time',
#   1.6,
#   1.5],
#  ['William Sanchez',
#   'Johnston, Fleming and Tanner',
#   'Naval architect',
#   'Kristaburgh',
#   'Saint Martin',
#   199960,
#   'Intern',
#   1.8,
#   1.5],
#  ['Tracy Holmes',
#   'Bullock-Carrillo',
#   'Energy manager',
#   'Wardfort',
#   'American Samoa',
#   250220,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Scott Martinez',
#   'Marshall-Holloway',
#   'Make',
#   'New Russellton',
#   'Hong Kong',
#   702170,
#   'Full Time',
#   4.0,
#   5.0],
#  ['Margaret Huerta',
#   'Wallace, Smith and Shepard',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'Eritrea',
#   761000,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Joel Hatfield',
#   'White, Mcclain and Cobb',
#   'Optometrist',
#   'Kristaburgh',
#   'Saint Lucia',
#   320030,
#   'Intern',
#   0.2,
#   1.5],
#  ['Grace Hester',
#   'Nelson-Li',
#   'Naval architect',
#   'Whitakerbury',
#   'Netherlands',
#   452360,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Jackson Allen',
#   'Nichols-James',
#   'Investment banker, corporate',
#   'Kristaburgh',
#   'Congo',
#   248290,
#   'Intern',
#   3.2,
#   3.4000000000000004],
#  ['Emily Allen',
#   'White, Mcclain and Cobb',
#   'Patent examiner',
#   'Aliciafort',
#   'Azerbaijan',
#   892050,
#   'Intern',
#   1.9,
#   1.5],
#  ['Joseph Church',
#   'Scott Inc',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Malaysia',
#   307620,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Walter Jones',
#   'Andrade LLC',
#   'Regulatory affairs officer',
#   'Ricardomouth',
#   'Panama',
#   746790,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Amanda Edwards',
#   'Andrade LLC',
#   'Regulatory affairs officer',
#   'Whiteside',
#   'United States Virgin Islands',
#   767500,
#   'Full Time',
#   4.0,
#   5.0],
#  ['Trevor Garcia',
#   'Taylor-Ramos',
#   'Garment/textile technologist',
#   'Aliciafort',
#   'Cuba',
#   772310,
#   'Intern',
#   3.1,
#   3.2],
#  ['Steven Hampton',
#   'Andrade LLC',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Bulgaria',
#   561240,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Diana Wright',
#   'Campos, Reynolds and Mccormick',
#   'Garment/textile technologist',
#   'New Cindychester',
#   'Armenia',
#   755470,
#   'Intern',
#   0.6,
#   1.5],
#  ['Samuel Stevenson',
#   'Bullock-Carrillo',
#   'Trading standards officer',
#   'Whiteside',
#   'French Polynesia',
#   997690,
#   'Full Time',
#   1.5,
#   1.5],
#  ['Patrick Curtis',
#   'White, Mcclain and Cobb',
#   'Actuary',
#   'New Russellton',
#   'Estonia',
#   273580,
#   'Full Time',
#   1.9,
#   1.5],
#  ['Joseph Ballard',
#   'Marshall-Holloway',
#   'Actuary',
#   'Whiteside',
#   'South Georgia and the South Sandwich Islands',
#   697730,
#   'Intern',
#   3.8,
#   4.6],
#  ['Susan Nixon',
#   'Campos, Reynolds and Mccormick',
#   'Armed forces logistics/support/administrative officer',
#   'Ricardomouth',
#   'Lebanon',
#   666900,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Brenda Allen',
#   'Matthews Inc',
#   'Trading standards officer',
#   'West Jamesview',
#   'Chile',
#   816360,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Michael Mercer',
#   'Marshall-Holloway',
#   'Sales promotion account executive',
#   'New Russellton',
#   'Antigua and Barbuda',
#   345500,
#   'Intern',
#   3.2,
#   3.4000000000000004],
#  ['Rebecca Bennett',
#   'Johnston, Fleming and Tanner',
#   'Armed forces logistics/support/administrative officer',
#   'West Jamesview',
#   'Jordan',
#   851800,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Dawn Hicks',
#   'Taylor-Ramos',
#   'Naval architect',
#   'Whiteside',
#   'Botswana',
#   711010,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Lisa Lewis',
#   'Scott Inc',
#   'Energy manager',
#   'Ricardomouth',
#   'Switzerland',
#   717820,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Barbara Page',
#   'Wallace, Smith and Shepard',
#   'Energy manager',
#   'West Jamesview',
#   'Martinique',
#   148260,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Gina Oneal',
#   'Scott Inc',
#   'Ergonomist',
#   'Whiteside',
#   'Guadeloupe',
#   987730,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Samantha Butler',
#   'Andrade LLC',
#   'Ergonomist',
#   'Aliciafort',
#   'Isle of Man',
#   639990,
#   'Intern',
#   1.7,
#   1.5],
#  ['Kristin Adams',
#   'Baker, Allen and Edwards',
#   'Energy manager',
#   'New Russellton',
#   'Cayman Islands',
#   380780,
#   'Full Time',
#   2.1,
#   1.5],
#  ['William Charles',
#   'Matthews Inc',
#   'Optometrist',
#   'Kristaburgh',
#   'Peru',
#   585590,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Stephen Lopez',
#   'Scott Inc',
#   'Equities trader',
#   'Wardfort',
#   'Grenada',
#   492280,
#   'Intern',
#   4.1,
#   5.199999999999999],
#  ['Melissa Garcia',
#   'Nichols-James',
#   'Naval architect',
#   'Wardfort',
#   'Ethiopia',
#   490720,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Dan Scott',
#   'Taylor-Ramos',
#   'Diplomatic Services operational officer',
#   'Whiteside',
#   'Niger',
#   219690,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Thomas Nichols',
#   'Scott Inc',
#   'Production engineer',
#   'Whiteside',
#   'Libyan Arab Jamahiriya',
#   180820,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Danny Bryan',
#   'Nelson-Li',
#   'Sales promotion account executive',
#   'Whitakerbury',
#   'Monaco',
#   402590,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Ricky Hahn',
#   'Wallace, Smith and Shepard',
#   'Trading standards officer',
#   'West Jamesview',
#   'Iran',
#   802400,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Lisa Vance',
#   'Wallace, Smith and Shepard',
#   'Armed forces logistics/support/administrative officer',
#   'Whitakerbury',
#   'Tuvalu',
#   607350,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Kyle Weiss',
#   'Nelson-Li',
#   'Optometrist',
#   'New Cindychester',
#   'New Zealand',
#   435870,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Judy Gonzalez',
#   'Campos, Reynolds and Mccormick',
#   'Optometrist',
#   'New Russellton',
#   'Suriname',
#   555730,
#   'Intern',
#   0.6,
#   1.5],
#  ['Michael Baker',
#   'Bullock-Carrillo',
#   'Production engineer',
#   'New Russellton',
#   'Namibia',
#   499220,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Michael Castro',
#   'Wallace, Smith and Shepard',
#   'Energy manager',
#   'Ricardomouth',
#   'Saint Lucia',
#   687320,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Katherine Perez',
#   'Andrade LLC',
#   'Production engineer',
#   'New Cindychester',
#   'Turks and Caicos Islands',
#   831950,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Kathy Vazquez',
#   'Baker, Allen and Edwards',
#   'Optometrist',
#   'Aliciafort',
#   'Austria',
#   537050,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Cynthia Wood',
#   'Wallace, Smith and Shepard',
#   'Trading standards officer',
#   'Whiteside',
#   'Saint Kitts and Nevis',
#   638000,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Justin Rivas',
#   'Johnston, Fleming and Tanner',
#   'Retail merchandiser',
#   'Ricardomouth',
#   'Hungary',
#   990920,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Hunter Mccormick',
#   'Bullock-Carrillo',
#   'Armed forces logistics/support/administrative officer',
#   'North Melissafurt',
#   'Tunisia',
#   331840,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Patrick Villarreal',
#   'Wallace, Smith and Shepard',
#   'Energy manager',
#   'Kristaburgh',
#   'Hungary',
#   160470,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Ryan Brown',
#   'Campos, Reynolds and Mccormick',
#   'Optometrist',
#   'Ricardomouth',
#   'Uganda',
#   406850,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Thomas Buck',
#   'Andrade LLC',
#   'Make',
#   'New Cindychester',
#   'Czech Republic',
#   270930,
#   'Full Time',
#   1.9,
#   1.5],
#  ['Sherri Wallace',
#   'Matthews Inc',
#   'Optometrist',
#   'Wardfort',
#   'Papua New Guinea',
#   534140,
#   'Full Time',
# ...
#   'Trading standards officer',
#   'New Russellton',
#   'Papua New Guinea',
#   356630,
#   'Full Time',
#   1.6,
#   1.5],
#  ['Monique Turner',
#   'Wallace, Smith and Shepard',
#   'Actuary',
#   'Wardfort',
#   'Bulgaria',
#   265470,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Kyle Riddle',
#   'Bullock-Carrillo',
#   'Trading standards officer',
#   'New Cindychester',
#   'Georgia',
#   781160,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Stacey Cervantes',
#   'James and Sons',
#   'Equities trader',
#   'North Melissafurt',
#   'Guam',
#   700630,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Theresa Mason',
#   'Scott Inc',
#   'Diplomatic Services operational officer',
#   'Wardfort',
#   'Djibouti',
#   73390,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Stephanie Flores',
#   'Thomas-Spencer',
#   'Garment/textile technologist',
#   'Ricardomouth',
#   'Croatia',
#   859710,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Tammy Murray',
#   'Bullock-Carrillo',
#   'Administrator',
#   'Kristaburgh',
#   'Nigeria',
#   356390,
#   'Intern',
#   0.9,
#   1.5],
#  ['Shane Miller',
#   'Bullock-Carrillo',
#   'Regulatory affairs officer',
#   'North Melissafurt',
#   'Lithuania',
#   827440,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Elizabeth Rivera',
#   'Bullock-Carrillo',
#   'Investment banker, corporate',
#   'Aliciafort',
#   'United States of America',
#   35490,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Robert Ferguson',
#   'Johnston, Fleming and Tanner',
#   'Make',
#   'Whiteside',
#   'Cocos (Keeling) Islands',
#   480080,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Christopher Ruiz',
#   'Marshall-Holloway',
#   'Actuary',
#   'Whitakerbury',
#   'Netherlands Antilles',
#   295160,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Judy Jimenez',
#   'Bullock-Carrillo',
#   'Naval architect',
#   'Ricardomouth',
#   'Nepal',
#   453980,
#   'Full Time',
#   2.4,
#   1.7999999999999998],
#  ['David Thomas',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'Ricardomouth',
#   'Guernsey',
#   271280,
#   'Full Time',
#   3.0,
#   3.0],
#  ['Larry Bruce',
#   'James and Sons',
#   'Sales promotion account executive',
#   'Ricardomouth',
#   'Bosnia and Herzegovina',
#   62790,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Richard Kelly',
#   'Campos, Reynolds and Mccormick',
#   'Make',
#   'North Melissafurt',
#   'United States Minor Outlying Islands',
#   970750,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Christopher Lee',
#   'Marshall-Holloway',
#   'Make',
#   'Ricardomouth',
#   'Andorra',
#   304140,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Wendy Day',
#   'Taylor-Ramos',
#   'Trading standards officer',
#   'West Jamesview',
#   'Saint Kitts and Nevis',
#   302500,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Riley Clark',
#   'Bullock-Carrillo',
#   'Actuary',
#   'Wardfort',
#   'Hong Kong',
#   89870,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Brandon Walsh',
#   'James and Sons',
#   'Diplomatic Services operational officer',
#   'Wardfort',
#   'Netherlands',
#   964970,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Philip Mendoza',
#   'James and Sons',
#   'Investment banker, corporate',
#   'New Cindychester',
#   'Serbia',
#   230630,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Anthony Richard',
#   'Andrade LLC',
#   'Actuary',
#   'North Melissafurt',
#   'Armenia',
#   785080,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Kyle Coleman',
#   'Baker, Allen and Edwards',
#   'Ergonomist',
#   'North Melissafurt',
#   'Sri Lanka',
#   199510,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Justin Mccarty',
#   'Johnston, Fleming and Tanner',
#   'Naval architect',
#   'New Cindychester',
#   'Sierra Leone',
#   356890,
#   'Intern',
#   2.4,
#   1.7999999999999998],
#  ['Tracy Brown',
#   'Nelson-Li',
#   'Energy manager',
#   'Whiteside',
#   "Cote d'Ivoire",
#   246860,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Monica Hill',
#   'Scott Inc',
#   'Retail merchandiser',
#   'North Melissafurt',
#   'Eritrea',
#   478850,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Jackie Oconnor',
#   'Baker, Allen and Edwards',
#   'Diplomatic Services operational officer',
#   'West Jamesview',
#   'Poland',
#   851360,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Lisa Warren',
#   'Campos, Reynolds and Mccormick',
#   'Radiographer, therapeutic',
#   'New Russellton',
#   'Uruguay',
#   337050,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Tracy Allen',
#   'Wallace, Smith and Shepard',
#   'Trading standards officer',
#   'New Russellton',
#   'Norfolk Island',
#   911830,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Juan Henderson',
#   'White, Mcclain and Cobb',
#   'Diplomatic Services operational officer',
#   'North Melissafurt',
#   'Iran',
#   233880,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Kevin Martin',
#   'Campos, Reynolds and Mccormick',
#   'Trading standards officer',
#   'Whitakerbury',
#   'Georgia',
#   742310,
#   'Full Time',
#   4.5,
#   6.0],
#  ['Steven Bailey',
#   'Andrade LLC',
#   'Garment/textile technologist',
#   'Wardfort',
#   'Saint Kitts and Nevis',
#   93560,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Juan Dawson',
#   'Marshall-Holloway',
#   'Diplomatic Services operational officer',
#   'Aliciafort',
#   'Switzerland',
#   713630,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Kyle Hamilton',
#   'Campos, Reynolds and Mccormick',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Palestinian Territory',
#   20500,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Stacey Mata',
#   'Nichols-James',
#   'Patent examiner',
#   'Whiteside',
#   'Holy See (Vatican City State)',
#   39290,
#   'Full Time',
#   3.5,
#   4.0],
#  ['Antonio Greene',
#   'Baker, Allen and Edwards',
#   'Administrator',
#   'Aliciafort',
#   'Syrian Arab Republic',
#   373420,
#   'Full Time',
#   0.3,
#   1.5],
#  ['Alicia Vincent',
#   'Johnston, Fleming and Tanner',
#   'Sales promotion account executive',
#   'Ricardomouth',
#   'Central African Republic',
#   643450,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Heather Lewis',
#   'White, Mcclain and Cobb',
#   'Trading standards officer',
#   'Ricardomouth',
#   'Northern Mariana Islands',
#   864770,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Gabrielle Robinson',
#   'White, Mcclain and Cobb',
#   'Ergonomist',
#   'New Russellton',
#   'El Salvador',
#   198940,
#   'Full Time',
#   4.3,
#   5.6],
#  ['John Petty',
#   'Thomas-Spencer',
#   'Investment banker, corporate',
#   'Whitakerbury',
#   'Libyan Arab Jamahiriya',
#   107890,
#   'Full Time',
#   2.4,
#   1.7999999999999998],
#  ['Tommy Williams',
#   'Nelson-Li',
#   'Optometrist',
#   'Whiteside',
#   'Faroe Islands',
#   1440,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Carrie Moore',
#   'Nelson-Li',
#   'Equities trader',
#   'Whiteside',
#   'Tokelau',
#   21800,
#   'Intern',
#   2.2,
#   1.5],
#  ['Claudia Pacheco',
#   'Wallace, Smith and Shepard',
#   'Naval architect',
#   'Whiteside',
#   'Grenada',
#   269470,
#   'Full Time',
#   3.0,
#   3.0],
#  ['Alex Kim',
#   'Scott Inc',
#   'Trading standards officer',
#   'Kristaburgh',
#   'Denmark',
#   705660,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['James Campbell',
#   'Bullock-Carrillo',
#   'Administrator',
#   'Wardfort',
#   'Somalia',
#   627200,
#   'Full Time',
#   4.0,
#   5.0],
#  ['Justin Underwood',
#   'Matthews Inc',
#   'Investment banker, corporate',
#   'Kristaburgh',
#   'Belgium',
#   942480,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Nicole Jordan',
#   'James and Sons',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'United Kingdom',
#   590690,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Rachel Carpenter',
#   'Wallace, Smith and Shepard',
#   'Administrator',
#   'Whiteside',
#   'Saint Kitts and Nevis',
#   640110,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Melissa Booth',
#   'Nichols-James',
#   'Investment banker, corporate',
#   'New Cindychester',
#   'Cuba',
#   285450,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Holly Small',
#   'Matthews Inc',
#   'Investment banker, corporate',
#   'New Russellton',
#   'Gambia',
#   239980,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['Anthony Doyle',
#   'White, Mcclain and Cobb',
#   'Armed forces logistics/support/administrative officer',
#   'North Melissafurt',
#   'Senegal',
#   237470,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Matthew Day',
#   'Baker, Allen and Edwards',
#   'Naval architect',
#   'New Russellton',
#   'New Zealand',
#   398380,
#   'Full Time',
#   2.5,
#   2.0],
#  ['Gregory Kennedy',
#   'Campos, Reynolds and Mccormick',
#   'Production engineer',
#   'Wardfort',
#   'Seychelles',
#   794100,
#   'Intern',
#   1.5,
#   1.5],
#  ['Travis Clark',
#   'White, Mcclain and Cobb',
#   'Make',
#   'New Cindychester',
#   'Kenya',
#   747640,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Richard Castro',
#   'Johnston, Fleming and Tanner',
#   'Optometrist',
#   'Kristaburgh',
#   'Thailand',
#   640860,
#   'Full Time',
#   3.5,
#   4.0],
#  ['Raymond Clark',
#   'Johnston, Fleming and Tanner',
#   'Retail merchandiser',
#   'Wardfort',
#   'Korea',
#   616190,
#   'Full Time',
#   4.6,
#   6.199999999999999],
#  ['Charles Griffin',
#   'Thomas-Spencer',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Trinidad and Tobago',
#   897560,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Robert Rogers',
#   'Wallace, Smith and Shepard',
#   'Patent examiner',
#   'North Melissafurt',
#   'Pitcairn Islands',
#   840600,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Stacey Heath',
#   'Andrade LLC',
#   'Actuary',
#   'Whitakerbury',
#   'Martinique',
#   281000,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Jennifer Foster',
#   'Johnston, Fleming and Tanner',
#   'Equities trader',
#   'Whitakerbury',
#   'Somalia',
#   24390,
#   'Full Time',
#   1.6,
#   1.5],
#  ['Mary Becker',
#   'Andrade LLC',
#   'Ergonomist',
#   'Wardfort',
#   'Switzerland',
#   755730,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Marcus Fisher',
#   'Taylor-Ramos',
#   'Diplomatic Services operational officer',
#   'Whiteside',
#   'Malta',
#   211200,
#   'Intern',
#   4.7,
#   6.4],
#  ['Christy Murphy',
#   'Wallace, Smith and Shepard',
#   'Armed forces logistics/support/administrative officer',
#   'Kristaburgh',
#   'Marshall Islands',
#   739860,
#   'Intern',
#   4.1,
#   5.199999999999999],
#  ['Miguel Morales',
#   'Marshall-Holloway',
#   'Diplomatic Services operational officer',
#   'Ricardomouth',
#   'Dominican Republic',
#   482130,
#   'Intern',
#   0.2,
#   1.5],
#  ['Christopher Lee',
#   'Campos, Reynolds and Mccormick',
#   'Naval architect',
#   'Aliciafort',
#   'Austria',
#   186670,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Amanda Caldwell',
#   'Bullock-Carrillo',
#   'Optometrist',
#   'North Melissafurt',
#   'Liechtenstein',
#   286490,
#   'Intern',
#   4.3,
#   5.6],
#  ['Christopher Harris',
#   'Marshall-Holloway',
#   'Regulatory affairs officer',
#   'Kristaburgh',
#   'Spain',
#   821760,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Timothy Griffin',
#   'Baker, Allen and Edwards',
#   'Equities trader',
#   'Whitakerbury',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   322220,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Yolanda Logan',
#   'Thomas-Spencer',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Bahrain',
#   720650,
#   'Intern',
#   3.3,
#   3.5999999999999996],
#  ['Felicia Thomas',
#   'White, Mcclain and Cobb',
#   'Diplomatic Services operational officer',
#   'Wardfort',
#   'Jersey',
#   408960,
#   'Intern',
#   2.1,
#   1.5],
#  ['Christine Peters',
#   'Taylor-Ramos',
#   'Naval architect',
#   'Aliciafort',
#   'Falkland Islands (Malvinas)',
#   278550,
#   'Intern',
#   3.9,
#   4.8],
#  ['Justin White',
#   'Baker, Allen and Edwards',
#   'Ergonomist',
#   'Ricardomouth',
#   'Thailand',
#   995750,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Brenda Sloan',
#   'Andrade LLC',
#   'Patent examiner',
#   'Kristaburgh',
#   'Netherlands Antilles',
#   116720,
#   'Intern',
#   4.8,
#   6.6],
#  ['Philip Brooks',
#   'Campos, Reynolds and Mccormick',
#   'Administrator',
#   'Wardfort',
#   'Ethiopia',
#   444080,
#   'Intern',
#   4.8,
#   6.6],
#  ['Robert Moore',
#   'Nichols-James',
#   'Diplomatic Services operational officer',
#   'New Russellton',
#   'Iceland',
#   729380,
#   'Full Time',
#   2.5,
#   2.0],
#  ['Carl Carney',
#   'Taylor-Ramos',
#   'Garment/textile technologist',
#   'North Melissafurt',
#   'Saint Barthelemy',
#   197810,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Bradley Mitchell',
#   'Wallace, Smith and Shepard',
#   'Patent examiner',
#   'Wardfort',
#   'Timor-Leste',
#   71190,
#   'Intern',
#   0.6,
#   1.5],
#  ['Mark Hill',
#   'Johnston, Fleming and Tanner',
#   'Make',
#   'Kristaburgh',
#   'Swaziland',
#   898610,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Cody Kline',
#   'Andrade LLC',
#   'Naval architect',
#   'Kristaburgh',
#   'Jersey',
#   619270,
#   'Intern',
#   2.4,
#   1.7999999999999998],
#  ['Debra Phillips',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'India',
#   733660,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Sarah Compton',
#   'Johnston, Fleming and Tanner',
#   'Naval architect',
#   'North Melissafurt',
#   'Eritrea',
#   438290,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Lisa Norris',
#   'Matthews Inc',
#   'Actuary',
#   'West Jamesview',
#   'Cambodia',
#   797710,
#   'Full Time',
#   0.5,
#   1.5],
#  ['Christopher Hall',
#   'Nichols-James',
#   'Optometrist',
#   'Whitakerbury',
#   'Burundi',
#   138250,
#   'Full Time',
#   1.7,
#   1.5],
#  ['Vincent Burton',
#   'Nichols-James',
#   'Actuary',
#   'Ricardomouth',
#   'Macedonia',
#   436170,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Amy Johnson',
#   'Scott Inc',
#   'Investment banker, corporate',
#   'Whitakerbury',
#   'Holy See (Vatican City State)',
#   138270,
#   'Intern',
#   0.9,
#   1.5],
#  ['Hunter Ward',
#   'Scott Inc',
#   'Retail merchandiser',
#   'Wardfort',
#   'Seychelles',
#   304850,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Scott Benitez',
#   'Baker, Allen and Edwards',
#   'Radiographer, therapeutic',
#   'North Melissafurt',
#   'Christmas Island',
#   848960,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Jesus Harrington',
#   'Scott Inc',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Kiribati',
#   264880,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Charles Johnston',
#   'Nelson-Li',
#   'Naval architect',
#   'Whiteside',
#   "Cote d'Ivoire",
#   202780,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Katherine Horn',
#   'Johnston, Fleming and Tanner',
#   'Retail merchandiser',
#   'New Cindychester',
#   'Denmark',
#   559050,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Tyler Clark',
#   'Andrade LLC',
#   'Make',
#   'Ricardomouth',
#   'Ukraine',
#   475050,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Devon Fowler',
#   'Nelson-Li',
#   'Regulatory affairs officer',
#   'New Cindychester',
#   'Libyan Arab Jamahiriya',
#   16209,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Joseph Williams',
#   'Scott Inc',
#   'Naval architect',
#   'Whitakerbury',
#   'Slovenia',
#   944160,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Sandra Duncan',
#   'Bullock-Carrillo',
#   'Administrator',
#   'Whiteside',
#   'Qatar',
#   683300,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Anthony Harris',
#   'Nelson-Li',
#   'Administrator',
#   'Whiteside',
#   'Liechtenstein',
#   914540,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Alex Kane',
#   'Thomas-Spencer',
#   'Production engineer',
#   'New Russellton',
#   'Germany',
#   317690,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Justin Cardenas',
#   'Johnston, Fleming and Tanner',
#   'Actuary',
#   'Whiteside',
#   'Niger',
#   374270,
#   'Full Time',
#   1.9,
#   1.5],
#  ['William Marshall',
#   'Andrade LLC',
#   'Diplomatic Services operational officer',
#   'Whiteside',
#   'Cocos (Keeling) Islands',
#   601090,
#   'Intern',
#   3.4,
#   3.8],
#  ['Valerie Robinson',
#   'James and Sons',
#   'Diplomatic Services operational officer',
#   'Ricardomouth',
#   'Colombia',
#   311590,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Omar George',
#   'Campos, Reynolds and Mccormick',
#   'Radiographer, therapeutic',
#   'New Russellton',
#   'Bolivia',
#   656900,
#   'Full Time',
#   2.4,
#   1.7999999999999998],
#  ['Charles Merritt',
#   'Andrade LLC',
#   'Ergonomist',
#   'New Cindychester',
#   'Barbados',
#   108260,
#   'Full Time',
#   0.5,
#   1.5],
#  ['Guy Rice',
#   'Matthews Inc',
#   'Equities trader',
#   'Kristaburgh',
#   'Montenegro',
#   247730,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Corey White',
#   'Baker, Allen and Edwards',
#   'Radiographer, therapeutic',
#   'Aliciafort',
#   'Syrian Arab Republic',
#   572960,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Ashley Harmon',
#   'Matthews Inc',
#   'Energy manager',
#   'New Russellton',
#   'Morocco',
#   778470,
#   'Intern',
#   1.5,
#   1.5],
#  ['James Hines',
#   'Baker, Allen and Edwards',
#   'Naval architect',
#   'Wardfort',
#   'Iran',
#   64810,
#   'Full Time',
#   1.0,
#   1.5],
#  ['William Lloyd',
#   'Baker, Allen and Edwards',
#   'Sales promotion account executive',
#   'New Russellton',
#   'Hong Kong',
#   643010,
#   'Full Time',
#   0.5,
#   1.5],
#  ['Jasmine Miller',
#   'White, Mcclain and Cobb',
#   'Make',
#   'Whitakerbury',
#   'Ethiopia',
#   885790,
#   'Intern',
#   4.8,
#   6.6],
#  ['Daniel Weiss',
#   'Campos, Reynolds and Mccormick',
#   'Patent examiner',
#   'Aliciafort',
#   'Lebanon',
#   821760,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Sara Wolfe',
#   'Andrade LLC',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'Tokelau',
#   750450,
#   'Full Time',
#   4.2,
#   5.4],
#  ...]

# %% [markdown]
# ### 120. Rearrange the columns in the below order. Overwrite to the current DataFrame object.

# %%
new_order = ["Name", "Employee_Job_Title", "Company_Name",
             "Employee_City", "Employee_Country", "Employment_Status",
             "Employee_Salary", "Employee_Rating", "Employee_Rating_New"]

df = df[new_order]
df
# Out:
#                   Name                       Employee_Job_Title  \
# 0       Spencer Adkins                          Equities trader
# 1         Julie Morton  Diplomatic Services operational officer
# 2         Matthew Hall               Regulatory affairs officer
# 3           Brad Scott                      Production engineer
# 4        Theresa Owens                      Production engineer
# ...                ...                                      ...
# 299995      Nancy Neal                              Optometrist
# 299996  Michele Butler                            Administrator
# 299997     Lynn Wilson                            Administrator
# 299998   Lindsey Keith                                     Make
# 299999   Karen Delgado                                  Actuary
#
#                         Company_Name      Employee_City  \
# 0                     James and Sons     New Russellton
# 1                      Nichols-James  North Melissafurt
# 2                          Scott Inc           Wardfort
# 3       Johnston, Fleming and Tanner     West Jamesview
# 4           Baker, Allen and Edwards          Whiteside
# ...                              ...                ...
# 299995              Bullock-Carrillo  North Melissafurt
# 299996  Johnston, Fleming and Tanner         Aliciafort
# 299997                 Nichols-James   New Cindychester
# 299998                 Nichols-James       Whitakerbury
# 299999                James and Sons     New Russellton
#
#              Employee_Country Employment_Status  Employee_Salary  \
# 0       Palestinian Territory         Full Time           321520
# 1            Marshall Islands         Full Time           589090
# 2                    Anguilla         Full Time           630890
# 3        Syrian Arab Republic         Full Time           116400
# 4                    Dominica         Full Time           523499
# ...                       ...               ...              ...
# 299995                  Samoa            Intern            99670
# 299996                   Cuba            Intern           949580
# 299997                Bolivia         Full Time           802830
# 299998         Western Sahara         Full Time           257240
# 299999         United Kingdom            Intern           575770
#
#         Employee_Rating  Employee_Rating_New
# 0                   3.9                  4.8
# 1                   4.3                  5.6
# 2                   3.1                  3.2
# 3                   3.1                  3.2
# 4                   4.8                  6.6
# ...                 ...                  ...
# 299995              3.3                  3.6
# 299996              2.6                  2.2
# 299997              0.6                  1.5
# 299998              2.4                  1.8
# 299999              3.3                  3.6
#
# [300000 rows x 9 columns]

# %% [markdown]
# ### 123. Drop the 'Name' column inplace from the DataFrame.

# %%
df.drop(columns = 'Name')
# Out:
#                              Employee_Job_Title                  Company_Name  \
# 0                               Equities trader                James and Sons
# 1       Diplomatic Services operational officer                 Nichols-James
# 2                    Regulatory affairs officer                     Scott Inc
# 3                           Production engineer  Johnston, Fleming and Tanner
# 4                           Production engineer      Baker, Allen and Edwards
# ...                                         ...                           ...
# 299995                              Optometrist              Bullock-Carrillo
# 299996                            Administrator  Johnston, Fleming and Tanner
# 299997                            Administrator                 Nichols-James
# 299998                                     Make                 Nichols-James
# 299999                                  Actuary                James and Sons
#
#             Employee_City       Employee_Country Employment_Status  \
# 0          New Russellton  Palestinian Territory         Full Time
# 1       North Melissafurt       Marshall Islands         Full Time
# 2                Wardfort               Anguilla         Full Time
# 3          West Jamesview   Syrian Arab Republic         Full Time
# 4               Whiteside               Dominica         Full Time
# ...                   ...                    ...               ...
# 299995  North Melissafurt                  Samoa            Intern
# 299996         Aliciafort                   Cuba            Intern
# 299997   New Cindychester                Bolivia         Full Time
# 299998       Whitakerbury         Western Sahara         Full Time
# 299999     New Russellton         United Kingdom            Intern
#
#         Employee_Salary  Employee_Rating  Employee_Rating_New
# 0                321520              3.9                  4.8
# 1                589090              4.3                  5.6
# 2                630890              3.1                  3.2
# 3                116400              3.1                  3.2
# 4                523499              4.8                  6.6
# ...                 ...              ...                  ...
# 299995            99670              3.3                  3.6
# 299996           949580              2.6                  2.2
# 299997           802830              0.6                  1.5
# 299998           257240              2.4                  1.8
# 299999           575770              3.3                  3.6
#
# [300000 rows x 8 columns]

# %% [markdown]
# ### 126. Rename the columns and store to a new DataFrame 'df_renamed':

# %% [markdown]
# 1. Employee_Rating -> Rating
# 2. Employee_Country -> Country
# 3. Employee_Salary -> Salary
# 4. Employee_Rating_New -> Rating_New
# 5. Employment_Status -> Employment_type
# 6. Employment_City -> City

# %%
df_renamed = df.rename(columns = {'Employee_Rating' : 'Rating', 'Employee_Country' : 'Country',
                                  'Employee_Salary' : 'Salary', 'Employee_Rating_New' : 'Rating_New', 'Employment_Status' : 'Employment_type' ,
                                  'Employment_City' : 'City'})

# %%
df_renamed
# Out:
#                   Name                       Employee_Job_Title  \
# 0       Spencer Adkins                          Equities trader
# 1         Julie Morton  Diplomatic Services operational officer
# 2         Matthew Hall               Regulatory affairs officer
# 3           Brad Scott                      Production engineer
# 4        Theresa Owens                      Production engineer
# ...                ...                                      ...
# 299995      Nancy Neal                              Optometrist
# 299996  Michele Butler                            Administrator
# 299997     Lynn Wilson                            Administrator
# 299998   Lindsey Keith                                     Make
# 299999   Karen Delgado                                  Actuary
#
#                         Company_Name      Employee_City  \
# 0                     James and Sons     New Russellton
# 1                      Nichols-James  North Melissafurt
# 2                          Scott Inc           Wardfort
# 3       Johnston, Fleming and Tanner     West Jamesview
# 4           Baker, Allen and Edwards          Whiteside
# ...                              ...                ...
# 299995              Bullock-Carrillo  North Melissafurt
# 299996  Johnston, Fleming and Tanner         Aliciafort
# 299997                 Nichols-James   New Cindychester
# 299998                 Nichols-James       Whitakerbury
# 299999                James and Sons     New Russellton
#
#                       Country Employment_type  Salary  Rating  Rating_New
# 0       Palestinian Territory       Full Time  321520     3.9         4.8
# 1            Marshall Islands       Full Time  589090     4.3         5.6
# 2                    Anguilla       Full Time  630890     3.1         3.2
# 3        Syrian Arab Republic       Full Time  116400     3.1         3.2
# 4                    Dominica       Full Time  523499     4.8         6.6
# ...                       ...             ...     ...     ...         ...
# 299995                  Samoa          Intern   99670     3.3         3.6
# 299996                   Cuba          Intern  949580     2.6         2.2
# 299997                Bolivia       Full Time  802830     0.6         1.5
# 299998         Western Sahara       Full Time  257240     2.4         1.8
# 299999         United Kingdom          Intern  575770     3.3         3.6
#
# [300000 rows x 9 columns]

# %% [markdown]
# ### 128. Count the number of NaN values in each column

# %%
df.isna().sum()
# Out:
# Name                   0
# Employee_Job_Title     0
# Company_Name           0
# Employee_City          0
# Employee_Country       0
# Employment_Status      0
# Employee_Salary        0
# Employee_Rating        0
# Employee_Rating_New    0
# dtype: int64

# %% [markdown]
# ### 131.  Map every Company_Name to a unique integer value. Name the new column "Company_ID".

# %% [markdown]
# For instance, if the data has 5 companies, "Company A" -> 1, "Company B" -> 2, "Company C" -> 3, "Company D" -> 4, "Company E" -> 5.

# %%
df['Company_ID'] = pd.factorize(df['Company_Name'])[0]

# %%
df
# Out:
#                   Name                       Employee_Job_Title  \
# 0       Spencer Adkins                          Equities trader
# 1         Julie Morton  Diplomatic Services operational officer
# 2         Matthew Hall               Regulatory affairs officer
# 3           Brad Scott                      Production engineer
# 4        Theresa Owens                      Production engineer
# ...                ...                                      ...
# 299995      Nancy Neal                              Optometrist
# 299996  Michele Butler                            Administrator
# 299997     Lynn Wilson                            Administrator
# 299998   Lindsey Keith                                     Make
# 299999   Karen Delgado                                  Actuary
#
#                         Company_Name      Employee_City  \
# 0                     James and Sons     New Russellton
# 1                      Nichols-James  North Melissafurt
# 2                          Scott Inc           Wardfort
# 3       Johnston, Fleming and Tanner     West Jamesview
# 4           Baker, Allen and Edwards          Whiteside
# ...                              ...                ...
# 299995              Bullock-Carrillo  North Melissafurt
# 299996  Johnston, Fleming and Tanner         Aliciafort
# 299997                 Nichols-James   New Cindychester
# 299998                 Nichols-James       Whitakerbury
# 299999                James and Sons     New Russellton
#
#              Employee_Country Employment_Status  Employee_Salary  \
# 0       Palestinian Territory         Full Time           321520
# 1            Marshall Islands         Full Time           589090
# 2                    Anguilla         Full Time           630890
# 3        Syrian Arab Republic         Full Time           116400
# 4                    Dominica         Full Time           523499
# ...                       ...               ...              ...
# 299995                  Samoa            Intern            99670
# 299996                   Cuba            Intern           949580
# 299997                Bolivia         Full Time           802830
# 299998         Western Sahara         Full Time           257240
# 299999         United Kingdom            Intern           575770
#
#         Employee_Rating  Employee_Rating_New  Company_ID
# 0                   3.9                  4.8           0
# 1                   4.3                  5.6           1
# 2                   3.1                  3.2           2
# 3                   3.1                  3.2           3
# 4                   4.8                  6.6           4
# ...                 ...                  ...         ...
# 299995              3.3                  3.6          11
# 299996              2.6                  2.2           3
# 299997              0.6                  1.5           1
# 299998              2.4                  1.8           1
# 299999              3.3                  3.6           0
#
# [300000 rows x 10 columns]

# %% [markdown]
# ### 133. Print the number of rows where 'City' belongs to the following list of cities.

# %% [markdown]
# Use the isin() method.

# %%
city_filter_list = ["New Russellton", "Whiteside", "Kristaburgh"]

row_count = len(df[df['Employee_City'].isin(city_filter_list)])
print(row_count)
# Out:
# 90054

# %% [markdown]
# ### 135. Print the name of the person with the 10th largest salary. If there are multiple people with the same salary, print all names.

# %%
salary10 = df.sort_values('Employee_Salary', ascending = False).iloc[9]['Employee_Salary']
df[df['Employee_Salary'] == salary10]['Name'].values
# Out:
# array(['Allen Chavez', 'David Ryan', 'Elizabeth Bell', 'Megan Petersen'],
#       dtype=object)

# %% [markdown]
# ### 136. Print a cross tabulation of Company Name and Employment Type.

# %%
pd.crosstab(df['Company_Name'], df['Employment_Status'])
# Out:
# Employment_Status               Full Time  Intern
# Company_Name
# Andrade LLC                         15964    4019
# Baker, Allen and Edwards            16118    3966
# Bullock-Carrillo                    16135    3928
# Campos, Reynolds and Mccormick      15930    3997
# James and Sons                      15888    3980
# Johnston, Fleming and Tanner        15832    3979
# Marshall-Holloway                   15871    3988
# Matthews Inc                        16082    4001
# Nelson-Li                           16027    4105
# Nichols-James                       15872    4039
# Scott Inc                           16396    3994
# Taylor-Ramos                        16086    4036
# Thomas-Spencer                      16037    4105
# Wallace, Smith and Shepard          15467    3897
# White, Mcclain and Cobb             16305    3956

# %% [markdown]
# ### 143-145. Print the 25th, 50th and 75th percentile of the Salary column

# %%
print(df['Employee_Salary'].quantile(0.25))
print(df['Employee_Salary'].quantile(0.5))
print(df['Employee_Salary'].quantile(0.75))
# Out:
# 250000.0
# 500780.0
# 749710.0

# %% [markdown]
# ### 147. Distribute the Salary column in 10 equal sized bins and label each bin from 1 to 10 and add a new column named "Labels"

# %%
bins = 10
labels = list(range(1,11))

df['Labels'] = pd.cut(df['Employee_Salary'], bins=bins, labels=labels)

# %%
df
# Out:
#                   Name                       Employee_Job_Title  \
# 0       Spencer Adkins                          Equities trader
# 1         Julie Morton  Diplomatic Services operational officer
# 2         Matthew Hall               Regulatory affairs officer
# 3           Brad Scott                      Production engineer
# 4        Theresa Owens                      Production engineer
# ...                ...                                      ...
# 299995      Nancy Neal                              Optometrist
# 299996  Michele Butler                            Administrator
# 299997     Lynn Wilson                            Administrator
# 299998   Lindsey Keith                                     Make
# 299999   Karen Delgado                                  Actuary
#
#                         Company_Name      Employee_City  \
# 0                     James and Sons     New Russellton
# 1                      Nichols-James  North Melissafurt
# 2                          Scott Inc           Wardfort
# 3       Johnston, Fleming and Tanner     West Jamesview
# 4           Baker, Allen and Edwards          Whiteside
# ...                              ...                ...
# 299995              Bullock-Carrillo  North Melissafurt
# 299996  Johnston, Fleming and Tanner         Aliciafort
# 299997                 Nichols-James   New Cindychester
# 299998                 Nichols-James       Whitakerbury
# 299999                James and Sons     New Russellton
#
#              Employee_Country Employment_Status  Employee_Salary  \
# 0       Palestinian Territory         Full Time           321520
# 1            Marshall Islands         Full Time           589090
# 2                    Anguilla         Full Time           630890
# 3        Syrian Arab Republic         Full Time           116400
# 4                    Dominica         Full Time           523499
# ...                       ...               ...              ...
# 299995                  Samoa            Intern            99670
# 299996                   Cuba            Intern           949580
# 299997                Bolivia         Full Time           802830
# 299998         Western Sahara         Full Time           257240
# 299999         United Kingdom            Intern           575770
#
#         Employee_Rating  Employee_Rating_New  Company_ID Labels
# 0                   3.9                  4.8           0      4
# 1                   4.3                  5.6           1      6
# 2                   3.1                  3.2           2      7
# 3                   3.1                  3.2           3      2
# 4                   4.8                  6.6           4      6
# ...                 ...                  ...         ...    ...
# 299995              3.3                  3.6          11      1
# 299996              2.6                  2.2           3     10
# 299997              0.6                  1.5           1      9
# 299998              2.4                  1.8           1      3
# 299999              3.3                  3.6           0      6
#
# [300000 rows x 11 columns]

# %% [markdown]
# # Pandas Notebook 4

# %% [markdown]
# ### 151. Sort DataFrame based on another list

# %%
import pandas as pd

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], columns=["col1", "col2"])

sort_list = ["C", "A", "D", "B"]

# start your code below
new_df = df.set_index('col1').loc[sort_list].reset_index()
# end your code here
print(new_df)
# Out:
#   col1  col2
# 0    C     3
# 1    A     1
# 2    D     4
# 3    B     2

# %% [markdown]
# ### 152. Insert a column at a specific location in a DataFrame with a name, "new_column"

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]],
                  columns=["col_A", "col_B"])

new_column = ["P", "Q", "R", "S"]
insert_position = 1 ## between col_A and col_B

## start your code below
df.insert(column = 'new_column', value =new_column, loc = 1)

## end your code here
df
# Out:
#   col_A new_column  col_B
# 0     A          P      1
# 1     B          Q      2
# 2     C          R      3
# 3     D          S      4

# %% [markdown]
# ### 154. Count the number of Non-NaN cells for each column

# %%
import numpy as np

# %%
df = pd.DataFrame([["A", np.NaN], [np.NaN, 2],
                   ["C", np.NaN], ["D", 4]],
                  columns=["col_A", "col_B"])

## start your code below
df.count()
## end your code here
# Out:
# col_A    3
# col_B    2
# dtype: int64

# %% [markdown]
# ### 156. Reverse DataFrame row-wise

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]],
                  columns=["col_A", "col_B"])

## start your code below
df[::-1]
## end our code here
# Out:
#   col_A  col_B
# 3     D      4
# 2     C      3
# 1     B      2
# 0     A      1

# %% [markdown]
# ### 157. Reverse DataFrame column-wise

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]],
                  columns=["col_A", "col_B"])

## start your code below
df.iloc[:, ::-1]
## end your code here
# Out:
#    col_B col_A
# 0      1     A
# 1      2     B
# 2      3     C
# 3      4     D

# %% [markdown]
# ### 158. Insert a row at an arbitrary position

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]],
                  columns=["col_A", "col_B"])

insert_pos = 1
insert_row = ["P", 5]

## start your code below
insert_df = pd.DataFrame([insert_row], columns=df.columns)
df = pd.concat([df.iloc[:insert_pos], insert_df, df.iloc[insert_pos:]]).reset_index(drop=True)
## end your code here
df
# Out:
#   col_A  col_B
# 0     A      1
# 1     P      5
# 2     B      2
# 3     C      3
# 4     D      4

# %% [markdown]
# ### 160. The cumulative sum of a column in DataFrame

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], columns=["col_A", "col_B"])

## start your code below
new_df = df.copy()
new_df['CumulativeSum'] = 0
for i in range(len(new_df)):
  new_df['CumulativeSum'].iloc[i] = new_df.iloc[i-1]['CumulativeSum'] + new_df.iloc[i]['col_B']
## end your code here

new_df
# Out:
# <ipython-input-354-4a98619f4269>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['CumulativeSum'].iloc[i] = new_df.iloc[i-1]['CumulativeSum'] + new_df.iloc[i]['col_B']
#   col_A  col_B  CumulativeSum
# 0     A      1              1
# 1     B      2              3
# 2     C      3              6
# 3     D      4             10

# %% [markdown]
# ### 165. Filter n-largest values from a DataFrame

# %%
df = pd.DataFrame([["A", 200], ["B", 400],
                   ["C", 100], ["D", 300]],
                  columns=["col_A", "col_B"])

k = 2

## start your code below
largest_k = df.sort_values(by = 'col_B', ascending=False).iloc[:k]
## end your code here

largest_k
# Out:
#   col_A  col_B
# 1     B    400
# 3     D    300

# %% [markdown]
# ### 169. Delete the rows that have NaN values

# %%
df = pd.DataFrame([["A", np.NaN], ["B", 2],
                   ["C", np.NaN], ["D", 4]],
                  columns=["col_A", "col_B"])

## start your code below
df = df.dropna()
## end your code here

print(df)
# Out:
#   col_A  col_B
# 1     B    2.0
# 3     D    4.0

# %% [markdown]
# ### 171. Fill NaN values with column mean

# %%
df = pd.DataFrame([["A", np.NaN], ["B", 2],
                   ["C", np.NaN], ["D", 4]],
                  columns=["col_A", "col_B"])

## start your code below
df = df.fillna(df['col_B'].mean())
## end your code here

print(df)
# Out:
#   col_A  col_B
# 0     A    3.0
# 1     B    2.0
# 2     C    3.0
# 3     D    4.0

# %% [markdown]
# ### 173. Swap two rows of a dataframe

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]],
                  columns=["col_A", "col_B"])

# swap second and last row
row_1, row_2 = 1, 3

## start your code below
df.iloc[[row_1,row_2]] = df.iloc[[row_2, row_1]]
## end your code here

print(df)
# Out:
#   col_A  col_B
# 0     A      1
# 1     D      4
# 2     C      3
# 3     B      2

# %% [markdown]
# ### 174. Create a column "col_D" that contains the 2nd largest value in each row

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 2, 9],
                   [2, 9, 3],
                   [8, 5, 4]],
                  columns=["col_A", "col_B", "col_C"])

list(df.iloc[1].values).sort()

# %%
a = [123,23]
a.sort()
a[1]
# Out:
# 123

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 2, 9],
                   [2, 9, 3],
                   [8, 5, 4]],
                  columns=["col_A", "col_B", "col_C"])

## start your code below
def second_largest(row):
    sorted_row = sorted(row, reverse=True)
    return sorted_row[1]

df['col_D'] = df.apply(second_largest, axis=1)
# end your code here

df
# Out:
#    col_A  col_B  col_C  col_D
# 0      4      1      5      4
# 1      5      2      9      5
# 2      2      9      3      3
# 3      8      5      4      5

# %% [markdown]
# ### 176. Get the Group "A" of the dataframe by first grouping the dataframe and then using the group key.

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["A", 3], ["D", 4]],
                  columns=["col_A", "col_B"])


## start your code below
group_A = df.groupby('col_A').get_group('A')
## end your code here

group_A
# Out:
#   col_A  col_B
# 0     A      1
# 2     A      3

# %% [markdown]
# ### 178. Get the rows where the value of "col_A" is equal to "col_B".

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 5, 9],
                   [2, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df[df['col_A'] == df['col_B']]
## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C
# 1      5      5      9

# %% [markdown]
# ### 180. Sort the Data on col_A and col_B

# %% [markdown]
# col_A -> Ascending
# col_B -> Descending

# %%
df = pd.DataFrame([[4, 1, 5],
                   [2, 5, 9],
                   [2, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df.sort_values(by = ['col_A', 'col_B'], ascending = [True, False])
## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C
# 2      2      9      3
# 1      2      5      9
# 0      4      1      5
# 3      8      5      8

# %% [markdown]
# ### 182. Get the mean of every column

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 5, 9],
                   [2, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
mean = df.mean()
## end your code here

print(mean)
# Out:
# col_A    4.75
# col_B    5.00
# col_C    6.25
# dtype: float64

# %% [markdown]
# ### 182. Get the mean of every row

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 5, 9],
                   [2, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
mean = df.mean(axis = 1)
## end your code here

print(mean)
# Out:
# 0    3.333333
# 1    6.333333
# 2    4.666667
# 3    7.000000
# dtype: float64

# %% [markdown]
# ### 183. Concatentate the two DataFrames row-wise

# %%
df1 = pd.DataFrame([["A", 1], ["B", 2]],
                  columns=["col_A", "col_B"])

df2 = pd.DataFrame([["A", 3], ["C", 4]],
                  columns=["col_A", "col_B"])

## start your code below
new_df = pd.concat([df1,df2])
## end your code here

print(new_df)
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2
# 0     A      3
# 1     C      4

# %% [markdown]
# ### 184. Concatentate the two DataFrames column-wise

# %%
df1 = pd.DataFrame([["A", 1], ["B", 2]],
                  columns=["col_A", "col_B"])

df2 = pd.DataFrame([["A", 3], ["C", 4]],
                  columns=["col_C", "col_D"])

## start your code below
new_df = pd.concat([df1,df2], axis = 1)
## end your code here

print(new_df)
# Out:
#   col_A  col_B col_C  col_D
# 0     A      1     A      3
# 1     B      2     C      4

# %% [markdown]
# ### 185. Change the last two values in the last column to [2,4]

# %% [markdown]
# Change 3 -> 2
# Change 8 -> 4
#
# **Note: You should do this in a single line of code**

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 5, 9],
                   [2, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
df.iloc[2:, -1] = [2, 4]
## end your code here

print(df)
# Out:
#    col_A  col_B  col_C
# 0      4      1      5
# 1      5      5      9
# 2      2      9      2
# 3      8      5      4

# %% [markdown]
# ### 186. Replace all '1' with '2'

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 5, 1],
                   [1, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
df = df.replace({1 : 2})
## end your code here

print(df)
# Out:
#    col_A  col_B  col_C
# 0      4      2      5
# 1      5      5      2
# 2      2      9      3
# 3      8      5      8

# %% [markdown]
# ### 187. Replace all '1' with '2' and '5' with '6' in a single line of code

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 5, 1],
                   [1, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
df = df.replace({1 : 2, 5 : 6})
## end your code here

print(df)
# Out:
#    col_A  col_B  col_C
# 0      4      2      6
# 1      6      6      2
# 2      2      9      3
# 3      8      6      8

# %% [markdown]
# ### 189. Convert the DataFrame to a list of lists. Don't include the header row.

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 5, 1],
                   [1, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
data_list = df.values.tolist()
## end your code here

print(data_list)
# Out:
# [[4, 1, 5], [5, 5, 1], [1, 9, 3], [8, 5, 8]]

# %% [markdown]
# ### 190. Add three new columns that show the cumulative sum of every column

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 5, 1],
                   [1, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
df[['cumsum1', 'cumsum2', 'cumsum3']] = 0
for i in range(len(df)) :
  df['cumsum1'][i] = df.iloc[i]['col_A']
  df['cumsum2'][i] = df['cumsum1'][i]+df.iloc[i]['col_B']
  df['cumsum3'][i] = df['cumsum2'][i]+df.iloc[i]['col_C']
## end your code here

print(df)
# Out:
#    col_A  col_B  col_C  cumsum1  cumsum2  cumsum3
# 0      4      1      5        4        5       10
# 1      5      5      1        5       10       11
# 2      1      9      3        1       10       13
# 3      8      5      8        8       13       21

# %% [markdown]
# ### 191. Print the cumulative sum of every row in a new column.

# %% [markdown]
# ### In other words, make a column that stores the cumulative sum of the (sum of every row).

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 5, 1],
                   [1, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
df['cumsum'] = df.sum(axis = 1)
## end your code here

print(df)
# Out:
#    col_A  col_B  col_C  cumsum
# 0      4      1      5      10
# 1      5      5      1      11
# 2      1      9      3      13
# 3      8      5      8      21

# %% [markdown]
# ### 194. GroupBy col_A, then find the sum of col_B and mean of col_C

# %%
df = pd.DataFrame([["A", 1, 5],
                   ["B", 5, 1],
                   ["C", 9, 3],
                   ["A", 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
df_A = df.groupby('col_A')
print(df_A['col_B'].sum())
print(df_A['col_C'].mean())
## end your code here
# Out:
# col_A
# A    6
# B    5
# C    9
# Name: col_B, dtype: int64
# col_A
# A    6.5
# B    1.0
# C    3.0
# Name: col_C, dtype: float64

# %% [markdown]
# ### 195. Find the correlation between every pair of column

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 5, 1],
                   [1, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df.corr()
## end your code here

print(new_df)
# Out:
#           col_A     col_B     col_C
# col_A  1.000000 -0.424264  0.599377
# col_B -0.424264  1.000000 -0.273434
# col_C  0.599377 -0.273434  1.000000

# %% [markdown]
# ### 198. Merge the two dataframes using the join() method on col_A.
# 참고) Note that the `join()` method is similar to the `merge()` method, but it operates on the index by default and has a simplified syntax.

# %%
df1 = pd.DataFrame([["A", 1], ["B", 2]],
                  columns=["col_A", "col_B"])

df2 = pd.DataFrame([["A", 3], ["C", 4]],
                  columns=["col_A", "col_C"])

## start your code below
df1 = df1.set_index('col_A')
df2 = df2.set_index('col_A')
new_df = df1.join(df2, how = 'outer').reset_index()
# end your code here

print(new_df)
# Out:
#   col_A  col_B  col_C
# 0     A    1.0    3.0
# 1     B    2.0    NaN
# 2     C    NaN    4.0

# %% [markdown]
# ### 199. Perform the full outer join on the two DataFrames.

# %%
df1 = pd.DataFrame([["A", 1], ["B", 2]],
                  columns=["col_A", "col_B"])

df2 = pd.DataFrame([["A", 3], ["C", 4]],
                  columns=["col_A", "col_C"])

## start your code below
df1 = df1.set_index('col_A')
df2 = df2.set_index('col_A')
new_df = df1.join(df2, how = 'outer').reset_index()
## end your code here

print(new_df)
# Out:
#   col_A  col_B  col_C
# 0     A    1.0    3.0
# 1     B    2.0    NaN
# 2     C    NaN    4.0

# %% [markdown]
# ### 200. Convert the DataFrame to a dictionary.

# %%
df = pd.DataFrame([[4, 1, 5],
                   [5, 5, 1],
                   [1, 9, 3],
                   [8, 5, 8]],
                  columns=["col_A", "col_B", "col_C"])


## start your code below
dict_df = df.to_dict()
## end your code here

dict_df
# Out:
# {'col_A': {0: 4, 1: 5, 2: 1, 3: 8},
#  'col_B': {0: 1, 1: 5, 2: 9, 3: 5},
#  'col_C': {0: 5, 1: 1, 2: 3, 3: 8}}

# %% [markdown]
# ### 끝.
# ### 고생하셨습니다.
